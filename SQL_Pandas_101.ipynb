# %% [markdown]
# https://jupyter-notebook.readthedocs.io/en/stable/notebook.html

# %% [raw]
# Work faster using keyboard shortcuts ⌨️
#
# a, b = insert cell above, below x, c, v, z = cut, copy, paste, undo m, y = change cell to markdown, code f = find h = help p = command palette dd = delete cell

# %% [raw]
# import numpy as np
# from sqlalchemy import create_engine
# import pandas as pd
#
# import urllib
# params = urllib.parse.quote_plus("DRIVER={SQL Server Native Client 11.0};"
#                                  "SERVER=GIANTPRO\DAXMAN;"
#                                  "DATABASE=WideWorldImportersDW;"
#                                  "Trusted_Connection=yes")
#
# engine = create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))
# print(engine.table_names())

# %% [raw]
# connection=engine.connect()
# # Build select statement for census table: stmt
# stmt = '''
# SELECT
# S.[Sale Key]
# ,C.Region
# ,C.Country
# ,C.[State Province]
# ,DC.Category AS [CustomerCategory]
# ,DC.Customer
# ,SI.Brand
# ,SI.Color
# ,SI.[Stock Item] AS [Product]
# ,S.[Invoice Date Key] AS [InvoiceDate]
# ,S.[Delivery Date Key] AS [DeliveryDate]
# ,E.Employee AS [SalesPerson]
# --,S.[WWI Invoice ID]
# ,S.[Package]
# ,S.[Quantity]
# ,S.[Unit Price]
# --,S.[Tax Rate]
# ,S.[Total Excluding Tax] AS [Sales]
#  --     ,S.[Tax Amount]
#  --     ,S.[Profit]
#  --     ,S.[Total Including Tax]
#  --     ,S.[Total Dry Items]
#  --     ,S.[Total Chiller Items]
#  --     ,S.[Lineage Key]
#  FROM [WideWorldImportersDW].[Fact].[Sale] S
#  INNER JOIN Dimension.City C
#  ON S.[City Key]=C.[City Key]
#  INNER JOIN Dimension.Customer DC
#  ON S.[Customer Key]=DC.[Customer Key]
#  INNER JOIN Dimension.[Stock Item] SI
#  ON S.[Stock Item Key]=SI.[Stock Item Key]
#  INNER JOIN Dimension.[Employee] E
#  ON S.[Salesperson Key]=E.[Employee Key]
#  '''
# results= connection.execute(stmt).fetchall()
# # Print the emitted statement to see the SQL emitted
# print(stmt)
# #print(results)
# #for item in results:
# #    print (item)
# df=pd.DataFrame(results)
# df.columns = results[0].keys()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DatasRev/source-files/master/csv/WWImporters_101.csv', delimiter=';')

# %%
df.head(5)
# Out:
#    Sale Key    Region        Country State Province CustomerCategory  \
# 0     64113  Americas  United States   Pennsylvania     Novelty Shop
# 1     90464  Americas  United States   Pennsylvania     Novelty Shop
# 2     57138  Americas  United States   Pennsylvania     Novelty Shop
# 3     54618  Americas  United States   Pennsylvania     Novelty Shop
# 4     57451  Americas  United States   Pennsylvania     Novelty Shop
#
#                        Customer Brand  Color  \
# 0  Wingtip Toys (Rose Tree, PA)   NaN  White
# 1  Wingtip Toys (Rose Tree, PA)   NaN  Black
# 2  Wingtip Toys (Rose Tree, PA)   NaN  White
# 3  Wingtip Toys (Rose Tree, PA)   NaN   Gray
# 4  Wingtip Toys (Rose Tree, PA)   NaN    NaN
#
#                                           Product InvoiceDate DeliveryDate  \
# 0  "The Gu" red shirt XML tag t-shirt (White) 5XL  2014-01-20   2014-01-21
# 1  "The Gu" red shirt XML tag t-shirt (Black) 6XL  2014-06-13   2014-06-14
# 2  "The Gu" red shirt XML tag t-shirt (White) 6XL  2013-12-06   2013-12-07
# 3                      USB rocket launcher (Gray)  2013-11-21   2013-11-22
# 4                Small 9mm replacement blades 9mm  2013-12-09   2013-12-10
#
#           SalesPerson Package  Quantity  Unit Price   Sales
# 0       Hudson Onslow    Each        72        18.0  1296.0
# 1       Sophia Hinton    Each       120        18.0  2160.0
# 2  Hudson Hollinworth    Each        84        18.0  1512.0
# 3       Hudson Onslow    Each         1        25.0    25.0
# 4           Lily Code    Each        40         4.1   164.0

# %%
df.head().style.highlight_null('yellow')
# Out:
# <style  type="text/css" >
#     #T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col6 {
#             background-color:  yellow;
#         }    #T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col6 {
#             background-color:  yellow;
#         }    #T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col6 {
#             background-color:  yellow;
#         }    #T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row3_col6 {
#             background-color:  yellow;
#         }    #T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row4_col6 {
#             background-color:  yellow;
#         }    #T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row4_col7 {
#             background-color:  yellow;
#         }</style>
# <table id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Sale Key</th>
#         <th class="col_heading level0 col1" >Region</th>
#         <th class="col_heading level0 col2" >Country</th>
#         <th class="col_heading level0 col3" >State Province</th>
#         <th class="col_heading level0 col4" >CustomerCategory</th>
#         <th class="col_heading level0 col5" >Customer</th>
#         <th class="col_heading level0 col6" >Brand</th>
#         <th class="col_heading level0 col7" >Color</th>
#         <th class="col_heading level0 col8" >Product</th>
#         <th class="col_heading level0 col9" >InvoiceDate</th>
#         <th class="col_heading level0 col10" >DeliveryDate</th>
#         <th class="col_heading level0 col11" >SalesPerson</th>
#         <th class="col_heading level0 col12" >Package</th>
#         <th class="col_heading level0 col13" >Quantity</th>
#         <th class="col_heading level0 col14" >Unit Price</th>
#         <th class="col_heading level0 col15" >Sales</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col0" class="data row0 col0" >64113</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col1" class="data row0 col1" >Americas</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col2" class="data row0 col2" >United States</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col3" class="data row0 col3" >Pennsylvania</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col4" class="data row0 col4" >Novelty Shop</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col5" class="data row0 col5" >Wingtip Toys (Rose Tree, PA)</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col6" class="data row0 col6" >nan</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col7" class="data row0 col7" >White</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col8" class="data row0 col8" >"The Gu" red shirt XML tag t-shirt (White) 5XL</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col9" class="data row0 col9" >2014-01-20</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col10" class="data row0 col10" >2014-01-21</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col11" class="data row0 col11" >Hudson Onslow</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col12" class="data row0 col12" >Each</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col13" class="data row0 col13" >72</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col14" class="data row0 col14" >18</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row0_col15" class="data row0 col15" >1296</td>
#     </tr>    <tr>
#         <th id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col0" class="data row1 col0" >90464</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col1" class="data row1 col1" >Americas</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col2" class="data row1 col2" >United States</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col3" class="data row1 col3" >Pennsylvania</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col4" class="data row1 col4" >Novelty Shop</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col5" class="data row1 col5" >Wingtip Toys (Rose Tree, PA)</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col6" class="data row1 col6" >nan</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col7" class="data row1 col7" >Black</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col8" class="data row1 col8" >"The Gu" red shirt XML tag t-shirt (Black) 6XL</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col9" class="data row1 col9" >2014-06-13</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col10" class="data row1 col10" >2014-06-14</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col11" class="data row1 col11" >Sophia Hinton</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col12" class="data row1 col12" >Each</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col13" class="data row1 col13" >120</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col14" class="data row1 col14" >18</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row1_col15" class="data row1 col15" >2160</td>
#     </tr>    <tr>
#         <th id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col0" class="data row2 col0" >57138</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col1" class="data row2 col1" >Americas</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col2" class="data row2 col2" >United States</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col3" class="data row2 col3" >Pennsylvania</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col4" class="data row2 col4" >Novelty Shop</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col5" class="data row2 col5" >Wingtip Toys (Rose Tree, PA)</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col6" class="data row2 col6" >nan</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col7" class="data row2 col7" >White</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col8" class="data row2 col8" >"The Gu" red shirt XML tag t-shirt (White) 6XL</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col9" class="data row2 col9" >2013-12-06</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col10" class="data row2 col10" >2013-12-07</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col11" class="data row2 col11" >Hudson Hollinworth</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col12" class="data row2 col12" >Each</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col13" class="data row2 col13" >84</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col14" class="data row2 col14" >18</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row2_col15" class="data row2 col15" >1512</td>
#     </tr>    <tr>
#         <th id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row3_col0" class="data row3 col0" >54618</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row3_col1" class="data row3 col1" >Americas</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row3_col2" class="data row3 col2" >United States</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row3_col3" class="data row3 col3" >Pennsylvania</td>
#         <td id="T_7397b9a8_adf7_11e9_b37b_d07e35c100c9row3_col4" class="data row3 col4" >Novelty Shop</td>
#         <td id="T_7

# %%
len(df)
# Out:
# 2000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
# Sale Key            2000 non-null int64
# Region              2000 non-null object
# Country             2000 non-null object
# State Province      2000 non-null object
# CustomerCategory    1164 non-null object
# Customer            2000 non-null object
# Brand               168 non-null object
# Color               1196 non-null object
# Product             2000 non-null object
# InvoiceDate         2000 non-null object
# DeliveryDate        1997 non-null object
# SalesPerson         2000 non-null object
# Package             2000 non-null object
# Quantity            2000 non-null int64
# Unit Price          2000 non-null float64
# Sales               2000 non-null float64
# dtypes: float64(2), int64(2), object(12)
# memory usage: 250.1+ KB

# %% [raw]
# If no index is specified, then a RangeIndex is created with labels from 0 to the number of rows+1.
# We can define the index when reading from a csv in the following way:
# data = pd.read_csv('data/data.csv', index_col='Sale Key')
# A good index identifies every row. That's why we are using WideWorldImportersDW Microsoft sample DataWarehouse, because it has Primary Keys.
# The default setting is that the index is dropped from the list of columns, you can change this by using the drop argument.
# data = pd.read_csv('data/data.csv', index_col='Sale Key', drop=False)
# Let's talk about indexes when we talk about SQL.

# %%
df.columns.values
# Out:
# array(['Sale Key', 'Region', 'Country', 'State Province',
#        'CustomerCategory', 'Customer', 'Brand', 'Color', 'Product',
#        'InvoiceDate', 'DeliveryDate', 'SalesPerson', 'Package',
#        'Quantity', 'Unit Price', 'Sales'], dtype=object)

# %%
columns=list(df)
columns
# Out:
# ['Sale Key',
#  'Region',
#  'Country',
#  'State Province',
#  'CustomerCategory',
#  'Customer',
#  'Brand',
#  'Color',
#  'Product',
#  'InvoiceDate',
#  'DeliveryDate',
#  'SalesPerson',
#  'Package',
#  'Quantity',
#  'Unit Price',
#  'Sales']

# %%
df.dtypes
# Out:
# Sale Key              int64
# Region               object
# Country              object
# State Province       object
# CustomerCategory     object
# Customer             object
# Brand                object
# Color                object
# Product              object
# InvoiceDate          object
# DeliveryDate         object
# SalesPerson          object
# Package              object
# Quantity              int64
# Unit Price          float64
# Sales               float64
# dtype: object

# %%
# Show memory used by each column
df.memory_usage(deep=True)
# Out:
# Index                   80
# Sale Key             16000
# Region              130000
# Country             140000
# State Province      134356
# CustomerCategory    107068
# Customer            153080
# Brand                69712
# Color                99738
# Product             199006
# InvoiceDate         134000
# DeliveryDate        133895
# SalesPerson         138521
# Package             122080
# Quantity             16000
# Unit Price           16000
# Sales                16000
# dtype: int64

# %%
df[columns[1]] = df[columns[1]].astype('category')
df[columns[2]] = df[columns[2]].astype('category')
df[columns[3]] = df[columns[3]].astype('category')
df[columns[4]] = df[columns[4]].astype('category')
df[['Package']] = df[['Package']].astype('category')
df[columns[6]] = df[columns[6]].astype('category')
df[columns[7]] = df[columns[7]].astype('category')
df[columns[9]] = df[columns[9]].astype('datetime64[ns]')
df[columns[10]] = df[columns[10]].astype('datetime64[ns]')
df[columns[13]] = df[columns[13]].astype('float64')
df[columns[14]] = df[columns[14]].astype('float64')
df[columns[15]] = df[columns[15]].astype('float64')

# %% [raw]
# https://appdividend.com/2019/01/26/pandas-set-index-example-python-set_index-tutorial/

# %%
df.set_index('Sale Key', drop=False, inplace=True) ## with the drop/False argument the Index col stays among the cols.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 64113 to 13332
# Data columns (total 16 columns):
# Sale Key            2000 non-null int64
# Region              2000 non-null category
# Country             2000 non-null category
# State Province      2000 non-null category
# CustomerCategory    1164 non-null category
# Customer            2000 non-null object
# Brand               168 non-null category
# Color               1196 non-null category
# Product             2000 non-null object
# InvoiceDate         2000 non-null datetime64[ns]
# DeliveryDate        1997 non-null datetime64[ns]
# SalesPerson         2000 non-null object
# Package             2000 non-null category
# Quantity            2000 non-null float64
# Unit Price          2000 non-null float64
# Sales               2000 non-null float64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 170.9+ KB

# %%
# The count method returns the number of non-missing values. By default, its axis parameter is set to 0:
df.count()
# Out:
# Sale Key            2000
# Region              2000
# Country             2000
# State Province      2000
# CustomerCategory    1164
# Customer            2000
# Brand                168
# Color               1196
# Product             2000
# InvoiceDate         2000
# DeliveryDate        1997
# SalesPerson         2000
# Package             2000
# Quantity            2000
# Unit Price          2000
# Sales               2000
# dtype: int64

# %%
df.isnull().sum()   # method chaining  summing the null values
# Out:
# Sale Key               0
# Region                 0
# Country                0
# State Province         0
# CustomerCategory     836
# Customer               0
# Brand               1832
# Color                804
# Product                0
# InvoiceDate            0
# DeliveryDate           3
# SalesPerson            0
# Package                0
# Quantity               0
# Unit Price             0
# Sales                  0
# dtype: int64

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 64113 to 13332
# Data columns (total 16 columns):
# Sale Key            2000 non-null int64
# Region              2000 non-null category
# Country             2000 non-null category
# State Province      2000 non-null category
# CustomerCategory    1164 non-null category
# Customer            2000 non-null object
# Brand               168 non-null category
# Color               1196 non-null category
# Product             2000 non-null object
# InvoiceDate         2000 non-null datetime64[ns]
# DeliveryDate        1997 non-null datetime64[ns]
# SalesPerson         2000 non-null object
# Package             2000 non-null category
# Quantity            2000 non-null float64
# Unit Price          2000 non-null float64
# Sales               2000 non-null float64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 604.1 KB

# %%
# Show memory used by each column
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.memory_usage.html
df.memory_usage(deep=True)
# Out:
# Index                16000
# Sale Key             16000
# Region                2145
# Country               2150
# State Province        2279
# CustomerCategory      2149
# Customer            153080
# Brand                 2146
# Color                 2757
# Product             199006
# InvoiceDate          16000
# DeliveryDate         16000
# SalesPerson         138521
# Package               2405
# Quantity             16000
# Unit Price           16000
# Sales                16000
# dtype: int64

# %%
df['Color'].hasnans    # we don't have nan or null values in this column
# Out:
# True

# %%
df.get_dtype_counts()
# Out:
# category          7
# datetime64[ns]    2
# float64           3
# int64             1
# object            3
# dtype: int64

# %%
df.shape
# Out:
# (2000, 16)

# %%
df.describe()
# Out:
#             Sale Key     Quantity   Unit Price         Sales
# count    2000.000000  2000.000000  2000.000000   2000.000000
# mean    81134.874000    39.826000    47.790170    797.835300
# std     62048.293207    53.953389   155.021347   1495.596966
# min        35.000000     1.000000     0.660000      9.600000
# 25%     31134.750000     5.000000    13.000000    100.000000
# 50%     65222.500000    10.000000    18.000000    240.000000
# 75%    118024.000000    70.000000    32.000000    960.000000
# max    228187.000000   360.000000  1899.000000  18990.000000

# %%
df=df[df['Sales']>=10]     # filter dataset based on a boolean
df.describe()
# Out:
#             Sale Key     Quantity   Unit Price         Sales
# count    1999.000000  1999.000000  1999.000000   1999.000000
# mean    81064.385193    39.844922    47.811676    798.229615
# std     61983.669580    53.960251   155.057152   1495.867201
# min        35.000000     1.000000     0.660000     13.000000
# 25%     31134.500000     5.000000    13.000000    100.000000
# 50%     65222.000000    10.000000    18.000000    240.000000
# 75%    117873.500000    70.000000    32.000000    960.000000
# max    228187.000000   360.000000  1899.000000  18990.000000

# %%
df.describe(include=[np.object])
# Out:
#        Customer                                         Product    SalesPerson
# count      1999                                            1999           1999
# unique        7                                             222             10
# top     Unknown  "The Gu" red shirt XML tag t-shirt (White) 3XS  Archer Lamble
# freq        836                                              19            228

# %%
df.describe(include=[np.number])
# Out:
#             Sale Key     Quantity   Unit Price         Sales
# count    1999.000000  1999.000000  1999.000000   1999.000000
# mean    81064.385193    39.844922    47.811676    798.229615
# std     61983.669580    53.960251   155.057152   1495.867201
# min        35.000000     1.000000     0.660000     13.000000
# 25%     31134.500000     5.000000    13.000000    100.000000
# 50%     65222.000000    10.000000    18.000000    240.000000
# 75%    117873.500000    70.000000    32.000000    960.000000
# max    228187.000000   360.000000  1899.000000  18990.000000

# %%
df.select_dtypes(include=[np.number])
# Out:
#           Sale Key  Quantity  Unit Price     Sales
# Sale Key
# 64113        64113      72.0       18.00   1296.00
# 90464        90464     120.0       18.00   2160.00
# 57138        57138      84.0       18.00   1512.00
# 54618        54618       1.0       25.00     25.00
# 57451        57451      40.0        4.10    164.00
# 57448        57448      10.0       45.00    450.00
# 57137        57137      10.0       24.00    240.00
# 54617        54617       1.0       34.00     34.00
# 51519        51519      90.0       37.00   3330.00
# 51517        51517       2.0      285.00    570.00
# 60139        60139      24.0        5.00    120.00
# 60138        60138       5.0       16.00     80.00
# 35              35       2.0       34.00     68.00
# 45484        45484      30.0       22.00    660.00
# 39477        39477      70.0       20.00   1400.00
# 8056          8056      90.0       45.00   4050.00
# 3118          3118      60.0       33.00   1980.00
# 3116          3116     150.0        2.10    315.00
# 8959          8959      25.0        1.05     26.25
# 8962          8962       6.0      240.00   1440.00
# 46041        46041      84.0        5.00    420.00
# 29222        29222      36.0        5.00    180.00
# 46809        46809      36.0        5.00    180.00
# 39476        39476      72.0        5.00    360.00
# 8961          8961       2.0       16.00     32.00
# 39478        39478       7.0      240.00   1680.00
# 60137        60137       9.0       32.00    288.00
# 57450        57450      10.0       32.00    320.00
# 57447        57447       9.0       32.00    288.00
# 54912        54912       5.0       32.00    160.00
# ...            ...       ...         ...       ...
# 183236      183236     125.0        2.04    255.00
# 183235      183235       3.0      230.00    690.00
# 182048      182048       9.0      230.00   2070.00
# 182047      182047     100.0      112.00  11200.00
# 178807      178807       3.0      240.00    720.00
# 184895      184895     156.0        2.90    452.40
# 184894      184894       7.0       30.00    210.00
# 184893      184893       2.0       35.00     70.00
# 184892      184892       8.0       25.00    200.00
# 182045      182045       4.0       25.00    100.00
# 196613      196613     108.0       18.00   1944.00
# 183237      183237      72.0       18.00   1296.00
# 178806      178806       6.0       32.00    192.00
# 182046      182046       2.0       32.00     64.00
# 183239      183239       8.0       32.00    256.00
# 178615      178615       8.0       32.00    256.00
# 178614      178614       8.0       13.00    104.00
# 189937      189937       9.0       35.00    315.00
# 189537      189537      25.0        1.05     26.25
# 50434        50434       8.0       32.00    256.00
# 60830        60830       7.0       32.00    224.00
# 59612        59612       3.0       32.00     96.00
# 59409        59409      90.0       32.00   2880.00
# 55419        55419       6.0       32.00    192.00
# 52420        52420      50.0       32.00   1600.00
# 59615        59615       8.0       13.00    104.00
# 59408        59408       9.0       13.00    117.00
# 55420        55420       6.0       13.00     78.00
# 50436        50436       6.0       13.00     78.00
# 13332        13332       9.0       13.00    117.00
#
# [1999 rows x 4 columns]

# %%
df.describe(include='all')
# Out:
#              Sale Key    Region        Country State Province  \
# count     1999.000000      1999           1999           1999
# unique            NaN         1              1              3
# top               NaN  Americas  United States   Pennsylvania
# freq              NaN      1999           1999           1089
# first             NaN       NaN            NaN            NaN
# last              NaN       NaN            NaN            NaN
# mean     81064.385193       NaN            NaN            NaN
# std      61983.669580       NaN            NaN            NaN
# min         35.000000       NaN            NaN            NaN
# 25%      31134.500000       NaN            NaN            NaN
# 50%      65222.000000       NaN            NaN            NaN
# 75%     117873.500000       NaN            NaN            NaN
# max     228187.000000       NaN            NaN            NaN
#
#        CustomerCategory Customer      Brand  Color  \
# count              1163     1999        168   1196
# unique                1        7          1      7
# top        Novelty Shop  Unknown  Northwind  Black
# freq               1163      836        168    442
# first               NaN      NaN        NaN    NaN
# last                NaN      NaN        NaN    NaN
# mean                NaN      NaN        NaN    NaN
# std                 NaN      NaN        NaN    NaN
# min                 NaN      NaN        NaN    NaN
# 25%                 NaN      NaN        NaN    NaN
# 50%                 NaN      NaN        NaN    NaN
# 75%                 NaN      NaN        NaN    NaN
# max                 NaN      NaN        NaN    NaN
#
#                                                Product          InvoiceDate  \
# count                                             1999                 1999
# unique                                             222                  443
# top     "The Gu" red shirt XML tag t-shirt (White) 3XS  2013-03-06 00:00:00
# freq                                                19                   17
# first                                              NaN  2013-01-01 00:00:00
# last                                               NaN  2016-05-31 00:00:00
# mean                                               NaN                  NaN
# std                                                NaN                  NaN
# min                                                NaN                  NaN
# 25%                                                NaN                  NaN
# 50%                                                NaN                  NaN
# 75%                                                NaN                  NaN
# max                                                NaN                  NaN
#
#                DeliveryDate    SalesPerson Package     Quantity   Unit Price  \
# count                  1996           1999    1999  1999.000000  1999.000000
# unique                  442             10       4          NaN          NaN
# top     2013-03-07 00:00:00  Archer Lamble    Each          NaN          NaN
# freq                     17            228    1923          NaN          NaN
# first   2013-01-02 00:00:00            NaN     NaN          NaN          NaN
# last    2016-05-29 00:00:00            NaN     NaN          NaN          NaN
# mean                    NaN            NaN     NaN    39.844922    47.811676
# std                     NaN            NaN     NaN    53.960251   155.057152
# min                     NaN            NaN     NaN     1.000000     0.660000
# 25%                     NaN            NaN     NaN     5.000000    13.000000
# 50%                     NaN            NaN     NaN    10.000000    18.000000
# 75%                     NaN            NaN     NaN    70.000000    32.000000
# max                     NaN            NaN     NaN   360.000000  1899.000000
#
#                Sales
# count    1999.000000
# unique           NaN
# top              NaN
# freq             NaN
# first            NaN
# last             NaN
# mean      798.229615
# std      1495.867201
# min        13.000000
# 25%       100.000000
# 50%       240.000000
# 75%       960.000000
# max     18990.000000

# %%
print (df.iloc[0]) # prints first line which is only useful if the index is sorted.
# Out:
# Sale Key                                                     64113
# Region                                                    Americas
# Country                                              United States
# State Province                                        Pennsylvania
# CustomerCategory                                      Novelty Shop
# Customer                              Wingtip Toys (Rose Tree, PA)
# Brand                                                          NaN
# Color                                                        White
# Product             "The Gu" red shirt XML tag t-shirt (White) 5XL
# InvoiceDate                                    2014-01-20 00:00:00
# DeliveryDate                                   2014-01-21 00:00:00
# SalesPerson                                          Hudson Onslow
# Package                                                       Each
# Quantity                                                        72
# Unit Price                                                      18
# Sales                                                         1296
# Name: 64113, dtype: object

# %%
df.sort_index(axis=0, inplace=True)
print (df.iloc[0]) # prints first line
# Out:
# Sale Key                                            35
# Region                                        Americas
# Country                                  United States
# State Province                            Pennsylvania
# CustomerCategory                          Novelty Shop
# Customer                  Wingtip Toys (Rose Tree, PA)
# Brand                                              NaN
# Color                                             Blue
# Product             Superhero action jacket (Blue) 3XL
# InvoiceDate                        2013-01-01 00:00:00
# DeliveryDate                       2013-01-02 00:00:00
# SalesPerson                             Kayla Woodcock
# Package                                           Each
# Quantity                                             2
# Unit Price                                          34
# Sales                                               68
# Name: 35, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 35 to 228187
# Data columns (total 16 columns):
# Sale Key            1999 non-null int64
# Region              1999 non-null category
# Country             1999 non-null category
# State Province      1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Brand               168 non-null category
# Color               1196 non-null category
# Product             1999 non-null object
# InvoiceDate         1999 non-null datetime64[ns]
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 170.8+ KB

# %%
df.isnull().sum().head()    # isnull gives back 1 and we are summing the 1 values to get the null values.
# Out:
# Sale Key              0
# Region                0
# Country               0
# State Province        0
# CustomerCategory    836
# dtype: int64

# %%
df['Package'].head(10)
# Out:
# Sale Key
# 35      Each
# 119     Each
# 584     Each
# 585     Each
# 674     Each
# 919     Each
# 920     Each
# 921     Each
# 984     Each
# 1199    Each
# Name: Package, dtype: category
# Categories (4, object): [Bag, Each, Packet, Pair]

# %%
df1 = df['Package']
df2 = df['Package']
df1 is df2
#The df1 and df2 variables are actually referring to the same object.
#Any change to one will change the other. Preventing this , you can use the copy method:
# The expression df['Package'] technically creates a view, and not a brand new copy.
# Out:
# True

# %%
df1 = df['Package']
df2 = df['Package']
df1 is df2
# The df1 and df2 variables are actually referring to the same object.
# Any change to one will change the other. Preventing this , you can use the copy method:
# The expression df['Package'] technically creates a view, and not a brand new copy.
# Out:
# True

# %%
df1 = df['Package'].copy()
df2 = df['Package'].copy()
df1 is df2
# Out:
# False

# %%
del df1
del df2

# %%
df.iloc[3:7,0:12]   # First slicing the index, then the columns
# Out:
#           Sale Key    Region        Country State Province CustomerCategory  \
# Sale Key
# 585            585  Americas  United States       Michigan              NaN
# 674            674  Americas  United States   Pennsylvania     Novelty Shop
# 919            919  Americas  United States   Pennsylvania     Novelty Shop
# 920            920  Americas  United States   Pennsylvania     Novelty Shop
#
#                                  Customer Brand  Color  \
# Sale Key
# 585                               Unknown   NaN    NaN
# 674       Wingtip Toys (Sarversville, PA)   NaN   Blue
# 919          Wingtip Toys (Stoneboro, PA)   NaN  White
# 920          Wingtip Toys (Stoneboro, PA)   NaN    NaN
#
#                                            Product InvoiceDate DeliveryDate  \
# Sale Key
# 585                 USB food flash drive - hot dog  2013-01-04   2013-01-05
# 674             Superhero action jacket (Blue) 3XL  2013-01-05   2013-01-06
# 919       DBA joke mug - two types of DBAs (White)  2013-01-07   2013-01-08
# 920                          Tape dispenser (Blue)  2013-01-07   2013-01-08
#
#          SalesPerson
# Sale Key
# 585        Taj Shand
# 674        Amy Trefl
# 919        Amy Trefl
# 920        Amy Trefl

# %% [raw]
# df.reset_index()   # We won't run this, it is only a memo here.

# %%
df[df['Sales'] >1000].head(3)
# Out:
#           Sale Key    Region        Country State Province CustomerCategory  \
# Sale Key
# 584            584  Americas  United States       Michigan              NaN
# 920            920  Americas  United States   Pennsylvania     Novelty Shop
# 984            984  Americas  United States   Pennsylvania     Novelty Shop
#
#                                  Customer Brand Color  \
# Sale Key
# 584                               Unknown   NaN   NaN
# 920          Wingtip Toys (Stoneboro, PA)   NaN   NaN
# 984       Wingtip Toys (Sarversville, PA)   NaN   NaN
#
#                                      Product InvoiceDate DeliveryDate  \
# Sale Key
# 584         Medium sized bubblewrap roll 20m  2013-01-04   2013-01-05
# 920                    Tape dispenser (Blue)  2013-01-07   2013-01-08
# 984       20 mm Double sided bubble wrap 50m  2013-01-07   2013-01-08
#
#          SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 584        Taj Shand    Each      80.0        20.0  1600.0
# 920        Amy Trefl    Each      60.0        32.0  1920.0
# 984        Amy Trefl    Each      80.0       108.0  8640.0

# %%
'''Value_counts counts all the occurrences of each unique value:'''
df['Color'].value_counts()
# Out:
# Black          442
# White          356
# Blue           209
# Gray            72
# Red             51
# Light Brown     35
# Yellow          31
# Name: Color, dtype: int64

# %%
df['Color'].value_counts(normalize=True)
# Out:
# Black          0.369565
# White          0.297659
# Blue           0.174749
# Gray           0.060201
# Red            0.042642
# Light Brown    0.029264
# Yellow         0.025920
# Name: Color, dtype: float64

# %%
df['Country'].value_counts()   # So we only have 1 Country which makes it useless unless I want to plot it on a map.
# Out:
# United States    1999
# Name: Country, dtype: int64

# %%
#Basic summary statistics
print(df['Sales'].min(), 'Min')
print(df['Sales'].max(), 'Max')
print(round(df['Sales'].mean(), 2), 'Mean')
print(df['Sales'].median(), 'Median')
print(df['Sales'].std(), 'Std')
print(df['Sales'].sum(), 'Sum')
print(df['Sales'].quantile(.50), '50th percentile') #median 50. precentile
print(df['InvoiceDate'].min(), 'Min')
print(df['InvoiceDate'].max(), 'Max')
# Out:
# 13.0 Min
# 18990.0 Max
# 798.23 Mean
# 240.0 Median
# 1495.8672014914646 Std
# 1595661.0 Sum
# 240.0 50th percentile
# 2013-01-01 00:00:00 Min
# 2016-05-31 00:00:00 Max

# %%
df['Sales'].describe()
# Out:
# count     1999.000000
# mean       798.229615
# std       1495.867201
# min         13.000000
# 25%        100.000000
# 50%        240.000000
# 75%        960.000000
# max      18990.000000
# Name: Sales, dtype: float64

# %%
df['InvoiceDate'].describe()
# Out:
# count                    1999
# unique                    443
# top       2013-03-06 00:00:00
# freq                       17
# first     2013-01-01 00:00:00
# last      2016-05-31 00:00:00
# Name: InvoiceDate, dtype: object

# %%
df['Brand'].value_counts()
# Out:
# Northwind    168
# Name: Brand, dtype: int64

# %%
df['Brand'].hasnans
# Out:
# True

# %%
df['Brand'].value_counts(dropna=False)
# Out:
# NaN          1831
# Northwind     168
# Name: Brand, dtype: int64

# %%
df['Brand'].value_counts(dropna=False, normalize=True)
# Out:
# NaN          0.915958
# Northwind    0.084042
# Name: Brand, dtype: float64

# %%
df.drop(['Brand'], axis=1, inplace=True)
df.head()
# Out:
#           Sale Key    Region        Country State Province CustomerCategory  \
# Sale Key
# 35              35  Americas  United States   Pennsylvania     Novelty Shop
# 119            119  Americas  United States   Pennsylvania     Novelty Shop
# 584            584  Americas  United States       Michigan              NaN
# 585            585  Americas  United States       Michigan              NaN
# 674            674  Americas  United States   Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0

# %%
col_rename = {'State Province':'State'}   # renaming with a dictionary
df = df.rename(columns=col_rename)
df.head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 35              35  Americas  United States  Pennsylvania     Novelty Shop
# 119            119  Americas  United States  Pennsylvania     Novelty Shop
# 584            584  Americas  United States      Michigan              NaN
# 585            585  Americas  United States      Michigan              NaN
# 674            674  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0

# %%
# The new columns is inserted into the last place of the columns
df['SalesCalc']=df['Quantity']*df['Unit Price']

# %%
df.head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 35              35  Americas  United States  Pennsylvania     Novelty Shop
# 119            119  Americas  United States  Pennsylvania     Novelty Shop
# 584            584  Americas  United States      Michigan              NaN
# 585            585  Americas  United States      Michigan              NaN
# 674            674  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales  \
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0
#
#           SalesCalc
# Sale Key
# 35             68.0
# 119           180.0
# 584          1600.0
# 585            64.0
# 674           136.0

# %%
df = df.drop('SalesCalc',axis='columns')
#or  del df['SalesCalc']
df.head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 35              35  Americas  United States  Pennsylvania     Novelty Shop
# 119            119  Americas  United States  Pennsylvania     Novelty Shop
# 584            584  Americas  United States      Michigan              NaN
# 585            585  Americas  United States      Michigan              NaN
# 674            674  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0

# %%
# Okay, now let's insert the new column into a specific place among the columns
Salesindex = df.columns.get_loc('Package') + 1
print(Salesindex)
df.insert(loc=Salesindex, column='SalesCalc2', value=df['Quantity']*df['Unit Price'])
df.head()
# Out:
# 12
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 35              35  Americas  United States  Pennsylvania     Novelty Shop
# 119            119  Americas  United States  Pennsylvania     Novelty Shop
# 584            584  Americas  United States      Michigan              NaN
# 585            585  Americas  United States      Michigan              NaN
# 674            674  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  SalesCalc2  Quantity  \
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each        68.0       2.0
# 119        2013-01-03  Kayla Woodcock    Each       180.0       6.0
# 584        2013-01-05       Taj Shand    Each      1600.0      80.0
# 585        2013-01-05       Taj Shand    Each        64.0       2.0
# 674        2013-01-06       Amy Trefl    Each       136.0       4.0
#
#           Unit Price   Sales
# Sale Key
# 35              34.0    68.0
# 119             30.0   180.0
# 584             20.0  1600.0
# 585             32.0    64.0
# 674             34.0   136.0

# %%
df = df.drop('SalesCalc2',axis='columns')

# %%
# so remember to use a list as the list of the columns you want to filter for!
df[['SalesPerson', 'Sales']].head(15)
# Out:
#              SalesPerson   Sales
# Sale Key
# 35        Kayla Woodcock    68.0
# 119       Kayla Woodcock   180.0
# 584            Taj Shand  1600.0
# 585            Taj Shand    64.0
# 674            Amy Trefl   136.0
# 919            Amy Trefl   104.0
# 920            Amy Trefl  1920.0
# 921            Amy Trefl   340.0
# 984            Amy Trefl  8640.0
# 1199           Lily Code    91.0
# 1200           Lily Code  2300.0
# 1201           Lily Code  1296.0
# 1202           Lily Code    78.0
# 1410       Sophia Hinton  1440.0
# 1411       Sophia Hinton    64.0

# %%
df.select_dtypes(include=['float64']).head()
# Out:
#           Quantity  Unit Price   Sales
# Sale Key
# 35             2.0        34.0    68.0
# 119            6.0        30.0   180.0
# 584           80.0        20.0  1600.0
# 585            2.0        32.0    64.0
# 674            4.0        34.0   136.0

# %%
df.select_dtypes(include=['number']).head()
# Out:
#           Sale Key  Quantity  Unit Price   Sales
# Sale Key
# 35              35       2.0        34.0    68.0
# 119            119       6.0        30.0   180.0
# 584            584      80.0        20.0  1600.0
# 585            585       2.0        32.0    64.0
# 674            674       4.0        34.0   136.0

# %%
import numpy as np
print(np.nan == np.nan)

print(np.nan > 5)

print(5 > np.nan)

print(np.nan != 5)
# Out:
# False
# False
# False
# True

# %%
# Use the nlargest method to select the top 100 movies by imdb_score:
df.nlargest(10, 'Sales').head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 31032        31032  Americas  United States      Michigan     Novelty Shop
# 2423          2423  Americas  United States  Pennsylvania     Novelty Shop
# 5536          5536  Americas  United States  Pennsylvania     Novelty Shop
# 135487      135487  Americas  United States      Michigan              NaN
# 43942        43942  Americas  United States      Michigan     Novelty Shop
#
#                                  Customer Color                     Product  \
# Sale Key
# 31032      Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
# 2423         Wingtip Toys (Stoneboro, PA)   NaN  Air cushion machine (Blue)
# 5536      Wingtip Toys (Sarversville, PA)   NaN  Air cushion machine (Blue)
# 135487                            Unknown   NaN  Air cushion machine (Blue)
# 43942      Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
#
#          InvoiceDate DeliveryDate    SalesPerson Package  Quantity  \
# Sale Key
# 31032     2013-07-03   2013-07-04  Hudson Onslow    Each      10.0
# 2423      2013-01-15   2013-01-16  Hudson Onslow    Each       8.0
# 5536      2013-02-02   2013-02-03    Jack Potter    Each       8.0
# 135487    2015-02-17   2015-02-18      Lily Code    Each       7.0
# 43942     2013-09-18   2013-09-19  Sophia Hinton    Each       6.0
#
#           Unit Price    Sales
# Sale Key
# 31032         1899.0  18990.0
# 2423          1899.0  15192.0
# 5536          1899.0  15192.0
# 135487        1899.0  13293.0
# 43942         1899.0  11394.0

# %%
df.nlargest(20, 'Sales').nsmallest(3, 'InvoiceDate')
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 2423          2423  Americas  United States  Pennsylvania     Novelty Shop
# 5536          5536  Americas  United States  Pennsylvania     Novelty Shop
# 7002          7002  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 2423         Wingtip Toys (Stoneboro, PA)   NaN
# 5536      Wingtip Toys (Sarversville, PA)   NaN
# 7002         Tailspin Toys (Tresckow, PA)   NaN
#
#                                      Product InvoiceDate DeliveryDate  \
# Sale Key
# 2423              Air cushion machine (Blue)  2013-01-15   2013-01-16
# 5536              Air cushion machine (Blue)  2013-02-02   2013-02-03
# 7002      32 mm Double sided bubble wrap 50m  2013-02-14   2013-02-15
#
#             SalesPerson Package  Quantity  Unit Price    Sales
# Sale Key
# 2423      Hudson Onslow    Each       8.0      1899.0  15192.0
# 5536        Jack Potter    Each       8.0      1899.0  15192.0
# 7002      Hudson Onslow    Each      80.0       112.0   8960.0

# %%
# Selecting the largest of each group by sorting
df.sort_values('Sales', ascending=False).head(5)
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 31032        31032  Americas  United States      Michigan     Novelty Shop
# 5536          5536  Americas  United States  Pennsylvania     Novelty Shop
# 2423          2423  Americas  United States  Pennsylvania     Novelty Shop
# 135487      135487  Americas  United States      Michigan              NaN
# 153971      153971  Americas  United States      Michigan     Novelty Shop
#
#                                  Customer Color                     Product  \
# Sale Key
# 31032      Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
# 5536      Wingtip Toys (Sarversville, PA)   NaN  Air cushion machine (Blue)
# 2423         Wingtip Toys (Stoneboro, PA)   NaN  Air cushion machine (Blue)
# 135487                            Unknown   NaN  Air cushion machine (Blue)
# 153971     Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
#
#          InvoiceDate DeliveryDate    SalesPerson Package  Quantity  \
# Sale Key
# 31032     2013-07-03   2013-07-04  Hudson Onslow    Each      10.0
# 5536      2013-02-02   2013-02-03    Jack Potter    Each       8.0
# 2423      2013-01-15   2013-01-16  Hudson Onslow    Each       8.0
# 135487    2015-02-17   2015-02-18      Lily Code    Each       7.0
# 153971    2015-05-20   2015-05-21  Archer Lamble    Each       6.0
#
#           Unit Price    Sales
# Sale Key
# 31032         1899.0  18990.0
# 5536          1899.0  15192.0
# 2423          1899.0  15192.0
# 135487        1899.0  13293.0
# 153971        1899.0  11394.0

# %%
df.sort_values(['Quantity','Unit Price'], ascending=False).head(10)
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 5161          5161  Americas  United States  Pennsylvania     Novelty Shop
# 82312        82312  Americas  United States      Michigan     Novelty Shop
# 74758        74758  Americas  United States  Pennsylvania              NaN
# 87104        87104  Americas  United States  Pennsylvania              NaN
# 20835        20835  Americas  United States  Pennsylvania     Novelty Shop
# 69127        69127  Americas  United States  Pennsylvania     Novelty Shop
# 21752        21752  Americas  United States  Pennsylvania     Novelty Shop
# 199115      199115  Americas  United States      Michigan     Novelty Shop
# 16148        16148  Americas  United States  Pennsylvania     Novelty Shop
# 2180          2180  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 5161         Wingtip Toys (Rose Tree, PA)   NaN
# 82312      Tailspin Toys (Brown City, MI)   NaN
# 74758                             Unknown   NaN
# 87104                             Unknown   NaN
# 20835     Wingtip Toys (Sarversville, PA)   NaN
# 69127        Tailspin Toys (Tresckow, PA)   NaN
# 21752        Wingtip Toys (Stoneboro, PA)   NaN
# 199115     Tailspin Toys (Brown City, MI)   NaN
# 16148        Tailspin Toys (Tresckow, PA)   NaN
# 2180      Wingtip Toys (Sarversville, PA)   NaN
#
#                                                   Product InvoiceDate  \
# Sale Key
# 5161      Black and orange fragile despatch tape 48mmx75m  2013-01-31
# 82312     Black and orange fragile despatch tape 48mmx75m  2014-05-02
# 74758     Black and orange fragile despatch tape 48mmx75m  2014-03-21
# 87104     Black and orange fragile despatch tape 48mmx75m  2014-05-29
# 20835                       Clear packaging tape 48mmx75m  2013-05-08
# 69127                       Clear packaging tape 48mmx75m  2014-02-17
# 21752               Shipping carton (Brown) 305x305x305mm  2013-05-13
# 199115              Shipping carton (Brown) 305x305x305mm  2016-01-04
# 16148               Shipping carton (Brown) 480x270x320mm  2013-04-11
# 2180                Shipping carton (Brown) 356x356x279mm  2013-01-14
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 5161       2013-02-01   Sophia Hinton    Each     360.0        3.70  1332.0
# 82312      2014-05-03  Kayla Woodcock    Each     360.0        3.70  1332.0
# 74758      2014-03-22   Sophia Hinton    Each     288.0        3.70  1065.6
# 87104      2014-05-30  Kayla Woodcock    Each     288.0        3.70  1065.6
# 20835      2013-05-09       Lily Code    Each     260.0        2.90   754.0
# 69127      2014-02-18       Taj Shand    Each     260.0        2.90   754.0
# 21752      2013-05-14       Taj Shand    Each     250.0        3.50   875.0
# 199115     2016-01-05  Anthony Grosse    Each     250.0        3.50   875.0
# 16148      2013-04-12   Sophia Hinton    Each     250.0        2.74   685.0
# 2180       2013-01-15  Kayla Woodcock    Each     250.0        2.04   510.0

# %% [raw]
# The drop_duplicates method in default mode keeps the first occurrence of each unique row. The subset parameter narrows it down to the column (or list of columns). In this example, only one row for each subset will be returned. As we sorted in the last step it means the top.

# %%
# Now, we use the drop_duplicates method to keep only the first row
df.sort_values('Sales', ascending=False).drop_duplicates(subset='SalesPerson').head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 31032        31032  Americas  United States      Michigan     Novelty Shop
# 5536          5536  Americas  United States  Pennsylvania     Novelty Shop
# 135487      135487  Americas  United States      Michigan              NaN
# 153971      153971  Americas  United States      Michigan     Novelty Shop
# 43942        43942  Americas  United States      Michigan     Novelty Shop
#
#                                  Customer Color                     Product  \
# Sale Key
# 31032      Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
# 5536      Wingtip Toys (Sarversville, PA)   NaN  Air cushion machine (Blue)
# 135487                            Unknown   NaN  Air cushion machine (Blue)
# 153971     Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
# 43942      Tailspin Toys (Brown City, MI)   NaN  Air cushion machine (Blue)
#
#          InvoiceDate DeliveryDate    SalesPerson Package  Quantity  \
# Sale Key
# 31032     2013-07-03   2013-07-04  Hudson Onslow    Each      10.0
# 5536      2013-02-02   2013-02-03    Jack Potter    Each       8.0
# 135487    2015-02-17   2015-02-18      Lily Code    Each       7.0
# 153971    2015-05-20   2015-05-21  Archer Lamble    Each       6.0
# 43942     2013-09-18   2013-09-19  Sophia Hinton    Each       6.0
#
#           Unit Price    Sales
# Sale Key
# 31032         1899.0  18990.0
# 5536          1899.0  15192.0
# 135487        1899.0  13293.0
# 153971        1899.0  11394.0
# 43942         1899.0  11394.0

# %%
# we can use sort_values with head again :
df.sort_values('DeliveryDate', ascending=False).head(10) \
.sort_values('Sales', ascending=True).head(3)
# Out:
#           Sale Key    Region        Country     State CustomerCategory  \
# Sale Key
# 227725      227725  Americas  United States  Michigan     Novelty Shop
# 227726      227726  Americas  United States  Michigan     Novelty Shop
# 227723      227723  Americas  United States  Michigan     Novelty Shop
#
#                                 Customer  Color  \
# Sale Key
# 227725    Tailspin Toys (Brown City, MI)  Black
# 227726    Tailspin Toys (Brown City, MI)  White
# 227723    Tailspin Toys (Brown City, MI)    NaN
#
#                                                   Product InvoiceDate  \
# Sale Key
# 227725       Developer joke mug - Oct 31 = Dec 25 (Black)  2016-05-28
# 227726    DBA joke mug - SELECT caffeine FROM mug (White)  2016-05-28
# 227723         Permanent marker black 5mm nib (Black) 5mm  2016-05-28
#
#          DeliveryDate    SalesPerson Package  Quantity  Unit Price  Sales
# Sale Key
# 227725     2016-05-29  Archer Lamble    Each       1.0        13.0   13.0
# 227726     2016-05-29  Archer Lamble    Each       2.0        13.0   26.0
# 227723     2016-05-29  Archer Lamble    Each      12.0         2.7   32.4

# %%
#Pass an integer to the .iloc indexer to select an entire row at that position:
df.loc[227725]
# Out:
# Sale Key                                                  227725
# Region                                                  Americas
# Country                                            United States
# State                                                   Michigan
# CustomerCategory                                    Novelty Shop
# Customer                          Tailspin Toys (Brown City, MI)
# Color                                                      Black
# Product             Developer joke mug - Oct 31 = Dec 25 (Black)
# InvoiceDate                                  2016-05-28 00:00:00
# DeliveryDate                                 2016-05-29 00:00:00
# SalesPerson                                        Archer Lamble
# Package                                                     Each
# Quantity                                                       1
# Unit Price                                                    13
# Sales                                                         13
# Name: 227725, dtype: object

# %%
#Specify the step size of the slice:
df.loc[35:227725:1000]
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 35              35  Americas  United States  Pennsylvania     Novelty Shop
# 65223        65223  Americas  United States  Pennsylvania     Novelty Shop
#
#                               Customer Color  \
# Sale Key
# 35        Wingtip Toys (Rose Tree, PA)  Blue
# 65223     Wingtip Toys (Rose Tree, PA)   NaN
#
#                                      Product InvoiceDate DeliveryDate  \
# Sale Key
# 35        Superhero action jacket (Blue) 3XL  2013-01-01   2013-01-02
# 65223       Small 9mm replacement blades 9mm  2014-01-24   2014-01-25
#
#                  SalesPerson Package  Quantity  Unit Price  Sales
# Sale Key
# 35            Kayla Woodcock    Each       2.0        34.0   68.0
# 65223     Hudson Hollinworth    Each      40.0         4.1  164.0

# %%
df.iloc[0]
# Out:
# Sale Key                                            35
# Region                                        Americas
# Country                                  United States
# State                                     Pennsylvania
# CustomerCategory                          Novelty Shop
# Customer                  Wingtip Toys (Rose Tree, PA)
# Color                                             Blue
# Product             Superhero action jacket (Blue) 3XL
# InvoiceDate                        2013-01-01 00:00:00
# DeliveryDate                       2013-01-02 00:00:00
# SalesPerson                             Kayla Woodcock
# Package                                           Each
# Quantity                                             2
# Unit Price                                          34
# Sales                                               68
# Name: 35, dtype: object

# %%
#This returns a Series:
df.iloc[[10,20,30]]
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 1200          1200  Americas  United States      Michigan              NaN
# 2167          2167  Americas  United States  Pennsylvania     Novelty Shop
# 3117          3117  Americas  United States  Pennsylvania     Novelty Shop
#
#                               Customer Color  \
# Sale Key
# 1200                           Unknown   Red
# 2167           Wingtip Toys (Shay, PA)   NaN
# 3117      Wingtip Toys (Rose Tree, PA)  Gray
#
#                                                     Product InvoiceDate  \
# Sale Key
# 1200                 Ride on toy sedan car (Red) 1/12 scale  2013-01-08
# 2167      Red and white urgent  heavy despatch tape  48m...  2013-01-14
# 3117                          Halloween skull mask (Gray) L  2013-01-18
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 1200       2013-01-09       Lily Code    Each      10.0       230.0  2300.0
# 2167       2013-01-15  Kayla Woodcock    Each      24.0         4.1    98.4
# 3117       2013-01-19   Hudson Onslow    Each     120.0        18.0  2160.0

# %%
#Use slice notation:
df.iloc[2:40:5]
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 584            584  Americas  United States      Michigan              NaN
# 921            921  Americas  United States  Pennsylvania     Novelty Shop
# 1202          1202  Americas  United States      Michigan              NaN
# 1571          1571  Americas  United States  Pennsylvania     Novelty Shop
# 2169          2169  Americas  United States  Pennsylvania     Novelty Shop
# 2422          2422  Americas  United States  Pennsylvania     Novelty Shop
# 3119          3119  Americas  United States  Pennsylvania     Novelty Shop
# 3514          3514  Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer        Color  \
# Sale Key
# 584                               Unknown          NaN
# 921          Wingtip Toys (Stoneboro, PA)         Blue
# 1202                              Unknown        White
# 1571         Wingtip Toys (Stoneboro, PA)        Black
# 2169              Wingtip Toys (Shay, PA)        White
# 2422         Wingtip Toys (Stoneboro, PA)  Light Brown
# 3119         Wingtip Toys (Rose Tree, PA)        White
# 3514      Wingtip Toys (Sarversville, PA)          NaN
#
#                                                     Product InvoiceDate  \
# Sale Key
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 921                      Superhero action jacket (Blue) 4XL  2013-01-07
# 1202           DBA joke mug - you might be a DBA if (White)  2013-01-08
# 1571      Developer joke mug - when your hammer is C++ (...  2013-01-10
# 2169               DBA joke mug - two types of DBAs (White)  2013-01-14
# 2422                  Halloween zombie mask (Light Brown) S  2013-01-15
# 3119           "The Gu" red shirt XML tag t-shirt (White) S  2013-01-18
# 3514                     20 mm Double sided bubble wrap 50m  2013-01-22
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 921        2013-01-08       Amy Trefl    Each      10.0        34.0   340.0
# 1202       2013-01-09       Lily Code    Each       6.0        13.0    78.0
# 1571       2013-01-11       Taj Shand    Each       3.0        13.0    39.0
# 2169       2013-01-15  Kayla Woodcock    Each       6.0        13.0    78.0
# 2422       2013-01-16   Hudson Onslow    Each      96.0        18.0  1728.0
# 3119       2013-01-19   Hudson Onslow    Each      12.0        18.0   216.0
# 3514       2013-01-23   Archer Lamble    Each      20.0       108.0  2160.0

# %%
df.loc[35:1000, 'Color':'Package']
# Out:
#           Color                                            Product  \
# Sale Key
# 35         Blue                 Superhero action jacket (Blue) 3XL
# 119         Red  RC vintage American toy coupe with remote cont...
# 584         NaN                   Medium sized bubblewrap roll 20m
# 585         NaN                     USB food flash drive - hot dog
# 674        Blue                 Superhero action jacket (Blue) 3XL
# 919       White           DBA joke mug - two types of DBAs (White)
# 920         NaN                              Tape dispenser (Blue)
# 921        Blue                 Superhero action jacket (Blue) 4XL
# 984         NaN                 20 mm Double sided bubble wrap 50m
#
#          InvoiceDate DeliveryDate     SalesPerson Package
# Sale Key
# 35        2013-01-01   2013-01-02  Kayla Woodcock    Each
# 119       2013-01-02   2013-01-03  Kayla Woodcock    Each
# 584       2013-01-04   2013-01-05       Taj Shand    Each
# 585       2013-01-04   2013-01-05       Taj Shand    Each
# 674       2013-01-05   2013-01-06       Amy Trefl    Each
# 919       2013-01-07   2013-01-08       Amy Trefl    Each
# 920       2013-01-07   2013-01-08       Amy Trefl    Each
# 921       2013-01-07   2013-01-08       Amy Trefl    Each
# 984       2013-01-07   2013-01-08       Amy Trefl    Each

# %%
df.iloc[0:100, [3,7]].head(3)
# Out:
#                  State                                            Product
# Sale Key
# 35        Pennsylvania                 Superhero action jacket (Blue) 3XL
# 119       Pennsylvania  RC vintage American toy coupe with remote cont...
# 584           Michigan                   Medium sized bubblewrap roll 20m

# %%
df['Sales'].sum()
# Out:
# 1595661.0

# %%
df[ df['Sale Key']==35 ].Sales.sum()
# Out:
# 68.0

# %%
df[ df['SalesPerson']=='Taj Shand' ].Sales.mean()
# Out:
# 814.0988151658767

# %%
df['Unit Price'].gt(30).head()
# Out:
# Sale Key
# 35      True
# 119    False
# 584    False
# 585     True
# 674     True
# Name: Unit Price, dtype: bool

# %%
df['Unit Price'].gt(30).count()
# Out:
# 1999

# %% [markdown]
# # Constructing multiple boolean conditions

# %%
criteria1 = df['CustomerCategory']=='Novelty Shop'
criteria2 = df['Quantity']>=270
criteria3 = ((df['State']=='Michigan') | (df['State']=='Pennsylvania'))

# %%
criteria_combined = criteria1 & criteria2 & criteria3
criteria_combined.head()
# Out:
# Sale Key
# 35     False
# 119    False
# 584    False
# 585    False
# 674    False
# dtype: bool

# %%
df[ criteria_combined ].head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 5161          5161  Americas  United States  Pennsylvania     Novelty Shop
# 82312        82312  Americas  United States      Michigan     Novelty Shop
#
#                                 Customer Color  \
# Sale Key
# 5161        Wingtip Toys (Rose Tree, PA)   NaN
# 82312     Tailspin Toys (Brown City, MI)   NaN
#
#                                                   Product InvoiceDate  \
# Sale Key
# 5161      Black and orange fragile despatch tape 48mmx75m  2013-01-31
# 82312     Black and orange fragile despatch tape 48mmx75m  2014-05-02
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 5161       2013-02-01   Sophia Hinton    Each     360.0         3.7  1332.0
# 82312      2014-05-03  Kayla Woodcock    Each     360.0         3.7  1332.0

# %%
SalesPersons = ['Sophia Hinton', 'Kayla Woodcock']
criteria4 =df['SalesPerson'].isin(SalesPersons)
criteria_combined_extended = criteria_combined | criteria4
df[ criteria_combined_extended ].head()
# Out:
#           Sale Key    Region        Country         State CustomerCategory  \
# Sale Key
# 35              35  Americas  United States  Pennsylvania     Novelty Shop
# 119            119  Americas  United States  Pennsylvania     Novelty Shop
# 1410          1410  Americas  United States  Pennsylvania              NaN
# 1411          1411  Americas  United States  Pennsylvania              NaN
# 2166          2166  Americas  United States  Pennsylvania     Novelty Shop
#
#                               Customer  Color  \
# Sale Key
# 35        Wingtip Toys (Rose Tree, PA)   Blue
# 119       Wingtip Toys (Rose Tree, PA)    Red
# 1410                           Unknown  Black
# 1411                           Unknown    NaN
# 2166           Wingtip Toys (Shay, PA)  White
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 1410                      Bubblewrap dispenser (Black) 1.5m  2013-01-09
# 1411            Dinosaur battery-powered slippers (Green) L  2013-01-09
# 2166      Developer joke mug - this code was generated b...  2013-01-14
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 1410       2013-01-10   Sophia Hinton    Each       6.0       240.0  1440.0
# 1411       2013-01-10   Sophia Hinton    Each       2.0        32.0    64.0
# 2166       2013-01-15  Kayla Woodcock    Each       3.0        13.0    39.0

# %%
# Indexes should be unique or sorted to perform well.
df.index.is_monotonic_increasing   # return if the index is monotonic increasing (only equal or increasing) values.
# Out:
# True

# %%
df.index.is_unique
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 35 to 228187
# Data columns (total 15 columns):
# Sale Key            1999 non-null int64
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# InvoiceDate         1999 non-null datetime64[ns]
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# dtypes: category(6), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 248.8+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 35 to 228187
# Data columns (total 15 columns):
# Sale Key            1999 non-null int64
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# InvoiceDate         1999 non-null datetime64[ns]
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# dtypes: category(6), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 248.8+ KB

# %%
df.set_index('InvoiceDate', inplace=True, drop=False)

# %%
df_summary = df[['Sales', 'InvoiceDate']].groupby('InvoiceDate').agg('sum').describe(percentiles=[.1, .9])
print(df_summary.info())
df_summary.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 1 columns):
# Sales    8 non-null float64
# dtypes: float64(1)
# memory usage: 128.0+ bytes
# None
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'InvoiceDate' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """Entry point for launching an IPython kernel.
#               Sales
# count    443.000000
# mean    3601.943567
# std     3775.600916
# min       52.000000
# 10%      384.100000
# 50%     2445.500000
# 90%     8368.440000
# max    25644.800000

# %%
print(df_summary.index)
# Out:
# Index(['count', 'mean', 'std', 'min', '10%', '50%', '90%', 'max'], dtype='object')

# %%
upper_10 = df_summary.loc['90%']
lower_10 = df_summary.loc['10%']
criteria = (df[['Sales', 'InvoiceDate']].groupby('InvoiceDate').agg('sum') < lower_10) | (df[['Sales', 'InvoiceDate']].groupby('InvoiceDate').agg('sum') > upper_10)
df_top_bottom_10 =df[['Sales', 'InvoiceDate']][criteria]
df_top_bottom_10.set_index('InvoiceDate', inplace=True)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: 'InvoiceDate' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.InvoiceDate.describe()
# Out:
# count                    1999
# unique                    443
# top       2013-03-06 00:00:00
# freq                       17
# first     2013-01-01 00:00:00
# last      2016-05-31 00:00:00
# Name: InvoiceDate, dtype: object

# %%
df_top_bottom_10.head()
# Out:
#              Sales
# InvoiceDate
# NaT           68.0
# NaT          180.0
# NaT            NaN
# NaT            NaN
# NaT          136.0

# %% [raw]
# >>> slb_close.plot(color='black', figsize=(12,6))
# >>> slb_top_bottom_10.plot(marker='o', style=' ', ms=4, color='lightgray')
# >>> xmin = criteria.index[0]
# >>> xmax = criteria.index[-1]
# >>> plt.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='black')

# %%
# %matplotlib inline
plt.ioff() 
df[['Sales']].groupby('InvoiceDate').agg('sum').plot(color='red', figsize=(12,6))
#df_top_bottom_10.plot(marker='o', style=' ', ms=4, color='lightgray')
xmin = criteria.index[0]
xmax = criteria.index[-1]
plt.hlines (y=[lower_10, upper_10], xmin=xmin, xmax=xmax, color='black')
plt.show()

# %% [raw]
# df[['Sales']].groupby('InvoiceDate').agg('sum').plot(color='black', figsize=(12,6))
# plt.hlines(y=[lower_10, upper_10], xmin=xmin, xmax=xmax,color='red')
# plt.fill_between(x=criteria.index, y1=lower_10, y2=df[['Sales']].groupby('InvoiceDate').values, color='black')
# plt.fill_between(x=criteria.index,y1=lower_10, y2=df[['Sales']].groupby('InvoiceDate').values, where=df['Sales'] < lower_10, color='green')
# plt.fill_between(x=criteria.index, y1=upper_10, y2=df[['Sales']].groupby('InvoiceDate').values, where=df['Sales'] > upper_10, color='red')

# %% [markdown]
# # Filtering with SQL Where clauses

# %%
df.set_index('Sale Key', inplace=True)
df.head()
# Out:
#             Region        Country         State CustomerCategory  \
# Sale Key
# 35        Americas  United States  Pennsylvania     Novelty Shop
# 119       Americas  United States  Pennsylvania     Novelty Shop
# 584       Americas  United States      Michigan              NaN
# 585       Americas  United States      Michigan              NaN
# 674       Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0

# %%
State = ['California', 'Pennsylvania', 'Michigan']
criteria_1 = df.State.isin(State)
criteria_2 = df.CustomerCategory == 'Novelty Shop'
criteria_3 = (df.Sales >= 10) & \
(df.Sales <= 180)
criteria_4=df.InvoiceDate>'2013-01-09'

# %%
criteria_final = (criteria_1 & criteria_2 & criteria_3  & criteria_4)

# %%
# Use boolean indexing to select only the rows that meet the final criteria:
select_columns = ['InvoiceDate','Color', 'State', 'Sales']
df.loc[criteria_final, select_columns].head(10)
# Out:
#          InvoiceDate   Color         State   Sales
# Sale Key
# 1570      2013-01-10   Black  Pennsylvania   26.00
# 1571      2013-01-10   Black  Pennsylvania   39.00
# 1572      2013-01-10     NaN  Pennsylvania   47.25
# 2166      2013-01-14   White  Pennsylvania   39.00
# 2167      2013-01-14     NaN  Pennsylvania   98.40
# 2168      2013-01-14  Yellow  Pennsylvania  125.00
# 2169      2013-01-14   White  Pennsylvania   78.00
# 2179      2013-01-14   White  Pennsylvania  117.00
# 3120      2013-01-18   White  Pennsylvania   13.00
# 3511      2013-01-22   White  Pennsylvania   78.00

# %% [markdown]
# # Query method

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html

# %%
qs = "State in @State and CustomerCategory == 'Novelty Shop'"
df_filtered2 = df.query(qs)
df_filtered2.head()
# Out:
#             Region        Country         State CustomerCategory  \
# Sale Key
# 35        Americas  United States  Pennsylvania     Novelty Shop
# 119       Americas  United States  Pennsylvania     Novelty Shop
# 674       Americas  United States  Pennsylvania     Novelty Shop
# 919       Americas  United States  Pennsylvania     Novelty Shop
# 920       Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer  Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)   Blue
# 119          Wingtip Toys (Rose Tree, PA)    Red
# 674       Wingtip Toys (Sarversville, PA)   Blue
# 919          Wingtip Toys (Stoneboro, PA)  White
# 920          Wingtip Toys (Stoneboro, PA)    NaN
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
# 919                DBA joke mug - two types of DBAs (White)  2013-01-07
# 920                                   Tape dispenser (Blue)  2013-01-07
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0
# 919        2013-01-08       Amy Trefl    Each       8.0        13.0   104.0
# 920        2013-01-08       Amy Trefl    Each      60.0        32.0  1920.0

# %% [markdown]
# # Where

# %% [markdown]
# The where method accepts a boolean condition. The default
# behavior is to return a Series the same size as the original which has all the
# False locations replaced with a missing value.

# %%
qs2= (df['Sales']>10)
df.where(qs2).head(5)
# Out:
#             Region        Country         State CustomerCategory  \
# Sale Key
# 35        Americas  United States  Pennsylvania     Novelty Shop
# 119       Americas  United States  Pennsylvania     Novelty Shop
# 584       Americas  United States      Michigan              NaN
# 585       Americas  United States      Michigan              NaN
# 674       Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0

# %% [markdown]
# # Masking DataFrame rows

# %% [raw]
# The mask method replaces data with missing values where the condition evaluates to False.

# %%
df['State'].mask(criteria_1).head(10)
# Out:
# Sale Key
# 35      NaN
# 119     NaN
# 584     NaN
# 585     NaN
# 674     NaN
# 919     NaN
# 920     NaN
# 921     NaN
# 984     NaN
# 1199    NaN
# Name: State, dtype: object

# %% [markdown]
# # Index alignment

# %% [raw]
# Producing Cartesian products
# Whenever two Series or DataFrames operate with another Series or DataFrame, the indexes
# (both the row index and column index) of each object align first before any operation
# begins. This index alignment happens silently and can be very surprising for those new to
# pandas. This alignment always creates a Cartesian product between the indexes unless the
# indexes are identical.

# %% [raw]
# An exception to the preceding example takes place when the indexes contain the same exact
# elements in the same order. When this occurs, a Cartesian product does not take place, and
# the indexes instead align by their position.

# %% [markdown]
# # Grouping and aggregating

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html

# %% [raw]
# df.groupby(['listcol_1', 'listcol_2', 'listcol_3', 'listcol_3'])
# df.groupby('single_column')

# %%
df.info()   # Mainly to check the index and the name of the columns here.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 35 to 228187
# Data columns (total 14 columns):
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# InvoiceDate         1999 non-null datetime64[ns]
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# dtypes: category(6), datetime64[ns](2), float64(3), object(3)
# memory usage: 153.2+ KB

# %%
df.groupby('State')['Sales'].agg('mean').head()
# Out:
# State
# Michigan        827.967066
# Oklahoma        760.032836
# Pennsylvania    785.918962
# Name: Sales, dtype: float64

# %%
df.groupby(['State', 'Color'])['Sales'].agg('mean').head(10)
# Out:
# State     Color
# Michigan  Black           563.331250
#           Blue           1700.547945
#           Gray            428.461538
#           Light Brown    1377.000000
#           Red            1075.681818
#           White           477.747748
#           Yellow          798.000000
# Oklahoma  Black           692.568182
#           Blue            976.263158
#           Gray           1512.000000
# Name: Sales, dtype: float64

# %%
df.groupby(['State', 'Color'])['Sales'].agg(np.mean).head(2)    # We can use numpy datatypes
# Out:
# State     Color
# Michigan  Black     563.331250
#           Blue     1700.547945
# Name: Sales, dtype: float64

# %%
df.groupby(['State', 'Color'])['Sales'].agg(np.std).head(5)
# Out:
# State     Color
# Michigan  Black           708.197870
#           Blue           2520.368811
#           Gray            483.750781
#           Light Brown     516.446319
#           Red             948.856825
# Name: Sales, dtype: float64

# %% [raw]
# Aggregations:  min max mean median sum count std var
# size describe nunique idxmin idxmax

# %%
df.groupby(['State', 'Color'])['Sales'].agg(['min', 'max', 'mean', 'sum']).head(10)
# Out:
#                          min      max         mean       sum
# State    Color
# Michigan Black          13.0   2850.0   563.331250   90133.0
#          Blue           25.0  10500.0  1700.547945  124140.0
#          Gray           32.0   1944.0   428.461538   11140.0
#          Light Brown   216.0   2160.0  1377.000000   22032.0
#          Red            75.0   2850.0  1075.681818   23665.0
#          White          13.0   2160.0   477.747748   53030.0
#          Yellow         25.0   2070.0   798.000000    7980.0
# Oklahoma Black          26.0   2850.0   692.568182   30473.0
#          Blue           50.0  10500.0   976.263158   18549.0
#          Gray         1512.0   1512.0  1512.000000    3024.0

# %%
group_cols = ['State', 'Color']
agg_dict = {'Sales':['sum', 'mean', 'size'],'Unit Price':['mean', 'var']}
df.groupby(group_cols).agg(agg_dict).head()
# Out:
#                          Sales                    Unit Price
#                            sum         mean size        mean           var
# State    Color
# Michigan Black         90133.0   563.331250  160   36.146875   3847.841500
#          Blue         124140.0  1700.547945   73   57.890411   3519.821157
#          Gray          11140.0   428.461538   26   26.615385     44.326154
#          Light Brown   22032.0  1377.000000   16   18.000000      0.000000
#          Red           23665.0  1075.681818   22  167.727273  12151.731602

# %% [markdown]
# Size returns the number of rows while count returns the number of non-missing values in a group.

# %%
group_cols = ['InvoiceDate','State', 'Color']
agg_dict = {'Sales':['sum', 'mean', 'size'],'Unit Price':['mean', 'var']}
df.groupby(group_cols).agg(agg_dict).head(10)
# Out:
#                                  Sales              Unit Price
#                                    sum    mean size       mean   var
# InvoiceDate State        Color
# 2013-01-01  Pennsylvania Blue     68.0    68.0    1       34.0   NaN
# 2013-01-02  Pennsylvania Red     180.0   180.0    1       30.0   NaN
# 2013-01-05  Pennsylvania Blue    136.0   136.0    1       34.0   NaN
# 2013-01-07  Pennsylvania Blue    340.0   340.0    1       34.0   NaN
#                          White   104.0   104.0    1       13.0   NaN
# 2013-01-08  Michigan     Black    91.0    91.0    1       13.0   NaN
#                          Red    2300.0  2300.0    1      230.0   NaN
#                          White  1374.0   687.0    2       15.5  12.5
# 2013-01-09  Pennsylvania Black  1440.0  1440.0    1      240.0   NaN
# 2013-01-10  Pennsylvania Black    65.0    32.5    2       13.0   0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 35 to 228187
# Data columns (total 14 columns):
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# InvoiceDate         1999 non-null datetime64[ns]
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# dtypes: category(6), datetime64[ns](2), float64(3), object(3)
# memory usage: 233.2+ KB

# %% [markdown]
# The agg method used on multiple columns creates an index object with two levels.
# The aggregating columns are the top level and the aggregating functions become the bottom level.
# In default mode, at the end of a groupby operation, pandas puts all of the grouping columns in
# the index. You can prevent it by setting it to False to avoid
# this behavior.  By default Pandas sorts the grouping columns.

# %%
group_cols = ['InvoiceDate','State', 'Color']
agg_dict = {'Sales':['sum', 'mean', 'size', 'min', 'max'],'Unit Price':['mean', 'var']}
df.groupby(group_cols, as_index=False).agg(agg_dict).head(10)
# Out:
#   InvoiceDate         State  Color   Sales                               \
#                                        sum    mean size     min     max
# 0  2013-01-01  Pennsylvania   Blue    68.0    68.0    1    68.0    68.0
# 1  2013-01-02  Pennsylvania    Red   180.0   180.0    1   180.0   180.0
# 2  2013-01-05  Pennsylvania   Blue   136.0   136.0    1   136.0   136.0
# 3  2013-01-07  Pennsylvania   Blue   340.0   340.0    1   340.0   340.0
# 4  2013-01-07  Pennsylvania  White   104.0   104.0    1   104.0   104.0
# 5  2013-01-08      Michigan  Black    91.0    91.0    1    91.0    91.0
# 6  2013-01-08      Michigan    Red  2300.0  2300.0    1  2300.0  2300.0
# 7  2013-01-08      Michigan  White  1374.0   687.0    2    78.0  1296.0
# 8  2013-01-09  Pennsylvania  Black  1440.0  1440.0    1  1440.0  1440.0
# 9  2013-01-10  Pennsylvania  Black    65.0    32.5    2    26.0    39.0
#
#   Unit Price
#         mean   var
# 0       34.0   NaN
# 1       30.0   NaN
# 2       34.0   NaN
# 3       34.0   NaN
# 4       13.0   NaN
# 5       13.0   NaN
# 6      230.0   NaN
# 7       15.5  12.5
# 8      240.0   NaN
# 9       13.0   0.0

# %%
#  You can define custom functions for aggregations
def pct_between_100_500(s):
    return s.between(100, 500).mean()

# %%
group_cols = ['InvoiceDate','State', 'Color']
agg_dict = {'Sales':['sum', 'mean', 'size', 'min', 'max', pct_between_100_500],'Unit Price':['mean', 'var']}
df.groupby(group_cols, as_index=False).agg(agg_dict).head(10)
# Out:
#   InvoiceDate         State  Color   Sales                               \
#                                        sum    mean size     min     max
# 0  2013-01-01  Pennsylvania   Blue    68.0    68.0    1    68.0    68.0
# 1  2013-01-02  Pennsylvania    Red   180.0   180.0    1   180.0   180.0
# 2  2013-01-05  Pennsylvania   Blue   136.0   136.0    1   136.0   136.0
# 3  2013-01-07  Pennsylvania   Blue   340.0   340.0    1   340.0   340.0
# 4  2013-01-07  Pennsylvania  White   104.0   104.0    1   104.0   104.0
# 5  2013-01-08      Michigan  Black    91.0    91.0    1    91.0    91.0
# 6  2013-01-08      Michigan    Red  2300.0  2300.0    1  2300.0  2300.0
# 7  2013-01-08      Michigan  White  1374.0   687.0    2    78.0  1296.0
# 8  2013-01-09  Pennsylvania  Black  1440.0  1440.0    1  1440.0  1440.0
# 9  2013-01-10  Pennsylvania  Black    65.0    32.5    2    26.0    39.0
#
#                       Unit Price
#   pct_between_100_500       mean   var
# 0                 0.0       34.0   NaN
# 1                 1.0       30.0   NaN
# 2                 1.0       34.0   NaN
# 3                 1.0       34.0   NaN
# 4                 1.0       13.0   NaN
# 5                 0.0       13.0   NaN
# 6                 0.0      230.0   NaN
# 7                 0.0       15.5  12.5
# 8                 0.0      240.0   NaN
# 9                 0.0       13.0   0.0

# %%
grouped=df.groupby(['State', 'Color'])
type(grouped)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
grouped.ngroups
# Out:
# 20

# %%
groups = list(grouped.groups.keys())
groups
# Out:
# [('Pennsylvania', 'Blue'),
#  ('Pennsylvania', 'Red'),
#  ('Michigan', nan),
#  ('Pennsylvania', 'White'),
#  ('Pennsylvania', nan),
#  ('Michigan', 'Black'),
#  ('Michigan', 'Red'),
#  ('Michigan', 'White'),
#  ('Pennsylvania', 'Black'),
#  ('Pennsylvania', 'Light Brown'),
#  ('Pennsylvania', 'Yellow'),
#  ('Pennsylvania', 'Gray'),
#  ('Michigan', 'Blue'),
#  ('Michigan', 'Light Brown'),
#  ('Oklahoma', 'White'),
#  ('Michigan', 'Gray'),
#  ('Michigan', 'Yellow'),
#  ('Oklahoma', nan),
#  ('Oklahoma', 'Black'),
#  ('Oklahoma', 'Blue'),
#  ('Oklahoma', 'Yellow'),
#  ('Oklahoma', 'Red'),
#  ('Oklahoma', 'Gray')]

# %% [markdown]
# # Grouping by continuous variables

# %%
df.Sales.describe()
# Out:
# count     1999.000000
# mean       798.229615
# std       1495.867201
# min         13.000000
# 25%        100.000000
# 50%        240.000000
# 75%        960.000000
# max      18990.000000
# Name: Sales, dtype: float64

# %%
bins = [-np.inf, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, np.inf]
cuts = pd.cut(df['Sales'], bins=bins)
cuts.head()
# Out:
# Sale Key
# 35      (-inf, 100.0]
# 119    (100.0, 200.0]
# 584     (1000.0, inf]
# 585     (-inf, 100.0]
# 674    (100.0, 200.0]
# Name: Sales, dtype: category
# Categories (11, interval[float64]): [(-inf, 100.0] < (100.0, 200.0] < (200.0, 300.0] < (300.0, 400.0] ... (700.0, 800.0] < (800.0, 900.0] < (900.0, 1000.0] < (1000.0, inf]]

# %%
cuts.value_counts()
# Out:
# (-inf, 100.0]      501
# (1000.0, inf]      483
# (100.0, 200.0]     367
# (200.0, 300.0]     259
# (300.0, 400.0]     100
# (400.0, 500.0]      77
# (600.0, 700.0]      69
# (800.0, 900.0]      44
# (500.0, 600.0]      36
# (900.0, 1000.0]     33
# (700.0, 800.0]      30
# Name: Sales, dtype: int64

# %%
cuts.value_counts(normalize=True)*100
# Out:
# (-inf, 100.0]      25.062531
# (1000.0, inf]      24.162081
# (100.0, 200.0]     18.359180
# (200.0, 300.0]     12.956478
# (300.0, 400.0]      5.002501
# (400.0, 500.0]      3.851926
# (600.0, 700.0]      3.451726
# (800.0, 900.0]      2.201101
# (500.0, 600.0]      1.800900
# (900.0, 1000.0]     1.650825
# (700.0, 800.0]      1.500750
# Name: Sales, dtype: float64

# %%
df.groupby(cuts)['Color'].value_counts(normalize=True) \
.round(3).head(15)*100
# Out:
# Sales           Color
# (-inf, 100.0]   Black     42.8
#                 White     39.7
#                 Blue      11.0
#                 Gray       3.4
#                 Red        1.7
#                 Yellow     1.4
# (100.0, 200.0]  Black     39.1
#                 White     34.1
#                 Blue      15.5
#                 Gray       5.5
#                 Red        3.2
#                 Yellow     2.7
# (200.0, 300.0]  Black     33.6
#                 Blue      29.9
#                 White     11.9
# Name: Color, dtype: float64

# %%
df.groupby(cuts)['State'].value_counts(normalize=True) \
.round(3).head(15)*100
# Out:
# Sales           State
# (-inf, 100.0]   Pennsylvania    54.3
#                 Michigan        35.9
#                 Oklahoma         9.8
# (100.0, 200.0]  Pennsylvania    55.0
#                 Michigan        36.2
#                 Oklahoma         8.7
# (200.0, 300.0]  Pennsylvania    52.9
#                 Michigan        34.4
#                 Oklahoma        12.7
# (300.0, 400.0]  Pennsylvania    55.0
#                 Michigan        39.0
#                 Oklahoma         6.0
# (400.0, 500.0]  Pennsylvania    51.9
#                 Michigan        32.5
#                 Oklahoma        15.6
# Name: State, dtype: float64

# %%
df.groupby(cuts)['Sales'].quantile(q=[.25, .5, .75]) \
.div(1).round(2)
# Out:
# Sales
# (-inf, 100.0]    0.25      32.00
#                  0.50      52.00
#                  0.75      78.00
# (100.0, 200.0]   0.25     117.00
#                  0.50     130.00
#                  0.75     162.00
# (200.0, 300.0]   0.25     224.00
#                  0.50     240.00
#                  0.75     264.45
# (300.0, 400.0]   0.25     320.00
#                  0.50     320.00
#                  0.75     355.20
# (400.0, 500.0]   0.25     432.00
#                  0.50     432.00
#                  0.75     459.00
# (500.0, 600.0]   0.25     531.55
#                  0.50     540.00
#                  0.75     570.00
# (600.0, 700.0]   0.25     648.00
#                  0.50     648.00
#                  0.75     688.80
# (700.0, 800.0]   0.25     720.00
#                  0.50     740.00
#                  0.75     787.20
# (800.0, 900.0]   0.25     864.00
#                  0.50     864.00
#                  0.75     886.20
# (900.0, 1000.0]  0.25     925.00
#                  0.50     960.00
#                  0.75     984.00
# (1000.0, inf]    0.25    1512.00
#                  0.50    1920.00
#                  0.75    2300.00
# Name: Sales, dtype: float64

# %%
df['SalesGroup']= pd.cut(df['Sales'], bins=bins)    # New column added to dataframe
df.head()
# Out:
#             Region        Country         State CustomerCategory  \
# Sale Key
# 35        Americas  United States  Pennsylvania     Novelty Shop
# 119       Americas  United States  Pennsylvania     Novelty Shop
# 584       Americas  United States      Michigan              NaN
# 585       Americas  United States      Michigan              NaN
# 674       Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales  \
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0
#
#               SalesGroup
# Sale Key
# 35         (-inf, 100.0]
# 119       (100.0, 200.0]
# 584        (1000.0, inf]
# 585        (-inf, 100.0]
# 674       (100.0, 200.0]

# %%
# bins = [-np.inf, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, np.inf
labels=['0-100', '101-200', '201-300', '301-400', '401-500', '501-600', '601-700', '701-800', '801-900', '901-1000', '1001-']
cuts2 = pd.cut(df['Sales'], bins=bins, labels=labels)
df.groupby(cuts2)['State'].value_counts(normalize=True) \
.round(3) \
.unstack() \
.style.highlight_max(axis=1)
# Out:
# <style  type="text/css" >
#     #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row0_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row1_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row2_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row3_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row4_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row5_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row6_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row7_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row8_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row9_col2 {
#             background-color:  yellow;
#         }    #T_76a5b412_adf7_11e9_8f61_d07e35c100c9row10_col2 {
#             background-color:  yellow;
#         }</style>
# <table id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9" >
# <thead>    <tr>
#         <th class="index_name level0" >State</th>
#         <th class="col_heading level0 col0" >Michigan</th>
#         <th class="col_heading level0 col1" >Oklahoma</th>
#         <th class="col_heading level0 col2" >Pennsylvania</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sales</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row0" class="row_heading level0 row0" >0-100</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row0_col0" class="data row0 col0" >0.359</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row0_col1" class="data row0 col1" >0.098</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row0_col2" class="data row0 col2" >0.543</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row1" class="row_heading level0 row1" >101-200</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row1_col0" class="data row1 col0" >0.362</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row1_col1" class="data row1 col1" >0.087</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row1_col2" class="data row1 col2" >0.55</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row2" class="row_heading level0 row2" >201-300</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row2_col0" class="data row2 col0" >0.344</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row2_col1" class="data row2 col1" >0.127</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row2_col2" class="data row2 col2" >0.529</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row3" class="row_heading level0 row3" >301-400</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row3_col0" class="data row3 col0" >0.39</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row3_col1" class="data row3 col1" >0.06</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row3_col2" class="data row3 col2" >0.55</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row4" class="row_heading level0 row4" >401-500</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row4_col0" class="data row4 col0" >0.325</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row4_col1" class="data row4 col1" >0.156</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row4_col2" class="data row4 col2" >0.519</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row5" class="row_heading level0 row5" >501-600</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row5_col0" class="data row5 col0" >0.306</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row5_col1" class="data row5 col1" >0.111</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row5_col2" class="data row5 col2" >0.583</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row6" class="row_heading level0 row6" >601-700</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row6_col0" class="data row6 col0" >0.246</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row6_col1" class="data row6 col1" >0.087</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row6_col2" class="data row6 col2" >0.667</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row7" class="row_heading level0 row7" >701-800</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row7_col0" class="data row7 col0" >0.367</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row7_col1" class="data row7 col1" >0.1</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row7_col2" class="data row7 col2" >0.533</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row8" class="row_heading level0 row8" >801-900</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row8_col0" class="data row8 col0" >0.432</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row8_col1" class="data row8 col1" >0.114</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row8_col2" class="data row8 col2" >0.455</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row9" class="row_heading level0 row9" >901-1000</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row9_col0" class="data row9 col0" >0.242</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row9_col1" class="data row9 col1" >0.152</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row9_col2" class="data row9 col2" >0.606</td>
#     </tr>    <tr>
#         <th id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9level0_row10" class="row_heading level0 row10" >1001-</th>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row10_col0" class="data row10 col0" >0.366</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row10_col1" class="data row10 col1" >0.095</td>
#         <td id="T_76a5b412_adf7_11e9_8f61_d07e35c100c9row10_col2" class="data row10 col2" >0.538</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# # Page 300 Tidy my data Keep the only data that sparks joy!

# %%
df.head()
# Out:
#             Region        Country         State CustomerCategory  \
# Sale Key
# 35        Americas  United States  Pennsylvania     Novelty Shop
# 119       Americas  United States  Pennsylvania     Novelty Shop
# 584       Americas  United States      Michigan              NaN
# 585       Americas  United States      Michigan              NaN
# 674       Americas  United States  Pennsylvania     Novelty Shop
#
#                                  Customer Color  \
# Sale Key
# 35           Wingtip Toys (Rose Tree, PA)  Blue
# 119          Wingtip Toys (Rose Tree, PA)   Red
# 584                               Unknown   NaN
# 585                               Unknown   NaN
# 674       Wingtip Toys (Sarversville, PA)  Blue
#
#                                                     Product InvoiceDate  \
# Sale Key
# 35                       Superhero action jacket (Blue) 3XL  2013-01-01
# 119       RC vintage American toy coupe with remote cont...  2013-01-02
# 584                        Medium sized bubblewrap roll 20m  2013-01-04
# 585                          USB food flash drive - hot dog  2013-01-04
# 674                      Superhero action jacket (Blue) 3XL  2013-01-05
#
#          DeliveryDate     SalesPerson Package  Quantity  Unit Price   Sales  \
# Sale Key
# 35         2013-01-02  Kayla Woodcock    Each       2.0        34.0    68.0
# 119        2013-01-03  Kayla Woodcock    Each       6.0        30.0   180.0
# 584        2013-01-05       Taj Shand    Each      80.0        20.0  1600.0
# 585        2013-01-05       Taj Shand    Each       2.0        32.0    64.0
# 674        2013-01-06       Amy Trefl    Each       4.0        34.0   136.0
#
#               SalesGroup
# Sale Key
# 35         (-inf, 100.0]
# 119       (100.0, 200.0]
# 584        (1000.0, inf]
# 585        (-inf, 100.0]
# 674       (100.0, 200.0]

# %%
df['Sale Key']=df.index
df_inv = df.pivot(index='Sale Key',
columns='State',
values=['Quantity','Unit Price','Sales'])
df_inv.head()
# Out:
#          Quantity                       Unit Price                        \
# State    Michigan Oklahoma Pennsylvania   Michigan Oklahoma Pennsylvania
# Sale Key
# 35            NaN      NaN          2.0        NaN      NaN         34.0
# 119           NaN      NaN          6.0        NaN      NaN         30.0
# 584          80.0      NaN          NaN       20.0      NaN          NaN
# 585           2.0      NaN          NaN       32.0      NaN          NaN
# 674           NaN      NaN          4.0        NaN      NaN         34.0
#
#             Sales
# State    Michigan Oklahoma Pennsylvania
# Sale Key
# 35            NaN      NaN         68.0
# 119           NaN      NaN        180.0
# 584        1600.0      NaN          NaN
# 585          64.0      NaN          NaN
# 674           NaN      NaN        136.0

# %% [markdown]
# # 324 Combining Pandas objects

# %%
dfp=df[df['State']=='Pennsylvania']
dfm=df[df['State']=='Michigan']
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1089 entries, 35 to 93556
# Data columns (total 16 columns):
# Region              1089 non-null category
# Country             1089 non-null category
# State               1089 non-null category
# CustomerCategory    808 non-null category
# Customer            1089 non-null object
# Color               663 non-null category
# Product             1089 non-null object
# InvoiceDate         1089 non-null datetime64[ns]
# DeliveryDate        1089 non-null datetime64[ns]
# SalesPerson         1089 non-null object
# Package             1089 non-null category
# Quantity            1089 non-null float64
# Unit Price          1089 non-null float64
# Sales               1089 non-null float64
# SalesGroup          1089 non-null category
# Sale Key            1089 non-null int64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 93.6+ KB

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 709 entries, 584 to 228187
# Data columns (total 16 columns):
# Region              709 non-null category
# Country             709 non-null category
# State               709 non-null category
# CustomerCategory    355 non-null category
# Customer            709 non-null object
# Color               418 non-null category
# Product             709 non-null object
# InvoiceDate         709 non-null datetime64[ns]
# DeliveryDate        706 non-null datetime64[ns]
# SalesPerson         709 non-null object
# Package             709 non-null category
# Quantity            709 non-null float64
# Unit Price          709 non-null float64
# Sales               709 non-null float64
# SalesGroup          709 non-null category
# Sale Key            709 non-null int64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 61.3+ KB

# %%
dfma=dfm.append(dfp)
dfma.info()
del dfma
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1798 entries, 584 to 93556
# Data columns (total 16 columns):
# Region              1798 non-null category
# Country             1798 non-null category
# State               1798 non-null category
# CustomerCategory    1163 non-null category
# Customer            1798 non-null object
# Color               1081 non-null category
# Product             1798 non-null object
# InvoiceDate         1798 non-null datetime64[ns]
# DeliveryDate        1795 non-null datetime64[ns]
# SalesPerson         1798 non-null object
# Package             1798 non-null category
# Quantity            1798 non-null float64
# Unit Price          1798 non-null float64
# Sales               1798 non-null float64
# SalesGroup          1798 non-null category
# Sale Key            1798 non-null int64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 153.8+ KB

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html#pandas.concat

# %%
dfma=pd.concat([dfp, dfm], axis=0)
dfma.info()
del dfma
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1798 entries, 35 to 228187
# Data columns (total 16 columns):
# Region              1798 non-null category
# Country             1798 non-null category
# State               1798 non-null category
# CustomerCategory    1163 non-null category
# Customer            1798 non-null object
# Color               1081 non-null category
# Product             1798 non-null object
# InvoiceDate         1798 non-null datetime64[ns]
# DeliveryDate        1795 non-null datetime64[ns]
# SalesPerson         1798 non-null object
# Package             1798 non-null category
# Quantity            1798 non-null float64
# Unit Price          1798 non-null float64
# Sales               1798 non-null float64
# SalesGroup          1798 non-null category
# Sale Key            1798 non-null int64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 153.8+ KB

# %%
dfma=pd.concat([dfp, dfm], 
axis='columns')
dfma.head()
del dfma

# %% [markdown]
# # concat, join, and merge

# %% [raw]
# Concat
# Pandas function
# Combines two or more pandas objects vertically or horizontally
# Aligns only on the index
# Errors whenever a duplicate appears in the index
# Defaults to outer join with option for inner

# %% [raw]
# Join
# DataFrame method
# Combines two or more pandas objects horizontally
# Aligns the calling DataFrame's column(s) or index with the other
# objects' index (and not the columns)
# Handles duplicate values on the joining columns/index by
# performing a cartesian product
# Defaults to left join with options for inner, outer, and right

# %% [raw]
# Merge
# DataFrame method
# Combines exactly two DataFrames horizontally
# Aligns the calling DataFrame's column(s)/index with the other
# DataFrame's column(s)/index
# Handles duplicate values on the joining columns/index by
# performing a cartesian product
# Defaults to inner join with options for left, outer, and right

# %% [markdown]
# # Time Series analysis

# %%
import datetime
date = datetime.date(year=2019, month=8, day=20)
time = datetime.time(hour=18, minute=10,
second=19, microsecond=463198)
dt = datetime.datetime(year=2019, month=8, day=20,
hour=12, minute=30, second=19,
microsecond=463198)
print("date is ", date)
print("time is", time)
print("datetime is", dt)
# Out:
# date is  2019-08-20
# time is 18:10:19.463198
# datetime is 2019-08-20 12:30:19.463198

# %%
# Let's construct and print out a timedelta object, the other major data type from the datetime module:
# You can add timedelta only to datetime objects.
td = datetime.timedelta(weeks=2, days=7, hours=2,
minutes=10, seconds=25.1, milliseconds=22, microseconds=3)
print(td)
# Out:
# 21 days, 2:10:25.122003

# %%
print('new date is', date + td)
print('new datetime is', dt + td)
# Out:
# new date is 2019-09-10
# new datetime is 2019-09-10 14:40:44.585201

# %%
pd.Timestamp(year=2012, month=12, day=21, hour=5,
minute=10, second=8, microsecond=99)
# Out:
# Timestamp('2012-12-21 05:10:08.000099')

# %%
print (pd.Timestamp('2016/1/10'))
print (pd.Timestamp('2014-5/10'))
print (pd.Timestamp('Jan 3, 2019 20:45.56') )
print ( pd.Timestamp('2016-01-05T05:34:43.123456789'))
# Out:
# 2016-01-10 00:00:00
# 2014-05-10 00:00:00
# 2019-01-03 20:45:33
# 2016-01-05 05:34:43.123456789

# %%
#It's also possible to pass in a single integer or float to the Timestamp constructor
#which returns a date equivalent to the number of nanoseconds after the Unix epoch, which is January 1, 1970:
pd.Timestamp(5000, unit='D')
# Out:
# Timestamp('1983-09-10 00:00:00')

# %%
'''Pandas provides the to_datetime function that works fairly similarly to the Timestamp constructor, but comes with a few different parameters for special
situations. See the following examples:'''
print (pd.to_datetime('2015-5-13'))
print( pd.to_datetime('2015-13-5', dayfirst=True))
print( pd.to_datetime('Start Date: Sep 30, 2017 Start Time: 1:30 pm',
format='Start Date: %b %d, %Y Start Time: %I:%M %p') )
print (pd.to_datetime(100, unit='D', origin='2013-1-1'))
print ( pd.to_datetime('2015-13-5', dayfirst=True))
# Out:
# 2015-05-13 00:00:00
# 2015-05-13 00:00:00
# 2017-09-30 13:30:00
# 2013-04-11 00:00:00
# 2015-05-13 00:00:00

# %% [markdown]
# ## Timedelta

# %%
print (pd.Timedelta('12 days 5 hours 3 minutes 123456789 nanoseconds'))
print (pd.Timedelta(days=5, minutes=7.34) )
print( pd.Timedelta(100, unit='W'))
print( pd.to_timedelta('67:15:45.454'))
print( pd.to_timedelta(pd.Series([20, 400]), unit='s'))
# Out:
# 12 days 05:03:00.123456
# 5 days 00:07:20.400000
# 700 days 00:00:00
# 2 days 19:15:45.454000
# 0   00:00:20
# 1   00:06:40
# dtype: timedelta64[ns]

# %%
print( pd.Timestamp('1/1/2017') + \
pd.Timedelta('12 days 5 hours 3 minutes') * 2)
# Out:
# 2017-01-25 10:06:00

# %%
ts = pd.Timestamp('2016-10-1 4:23:23.9')
print( ts.ceil('h'))
# Out:
# 2016-10-01 05:00:00

# %% [markdown]
# https://docs.python.org/3/library/datetime.html
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timedeltas.html

# %% [markdown]
# # Slicing time series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1999 entries, 35 to 228187
# Data columns (total 16 columns):
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# InvoiceDate         1999 non-null datetime64[ns]
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# SalesGroup          1999 non-null category
# Sale Key            1999 non-null int64
# dtypes: category(7), datetime64[ns](2), float64(3), int64(1), object(3)
# memory usage: 250.9+ KB

# %%
df.set_index('InvoiceDate', inplace=True)
df.sort_index()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1999 entries, 2013-01-01 to 2016-05-31
# Data columns (total 15 columns):
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# SalesGroup          1999 non-null category
# Sale Key            1999 non-null int64
# dtypes: category(7), datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 155.3+ KB

# %%
df.loc['2014-05-12']
# Out:
#                Region        Country         State CustomerCategory  \
# InvoiceDate
# 2014-05-12   Americas  United States  Pennsylvania     Novelty Shop
# 2014-05-12   Americas  United States  Pennsylvania     Novelty Shop
# 2014-05-12   Americas  United States  Pennsylvania     Novelty Shop
# 2014-05-12   Americas  United States  Pennsylvania     Novelty Shop
# 2014-05-12   Americas  United States      Michigan     Novelty Shop
# 2014-05-12   Americas  United States      Michigan     Novelty Shop
#
#                                    Customer  Color  \
# InvoiceDate
# 2014-05-12     Tailspin Toys (Tresckow, PA)    NaN
# 2014-05-12     Tailspin Toys (Tresckow, PA)  White
# 2014-05-12     Tailspin Toys (Tresckow, PA)  Black
# 2014-05-12     Tailspin Toys (Tresckow, PA)    NaN
# 2014-05-12   Tailspin Toys (Brown City, MI)    NaN
# 2014-05-12   Tailspin Toys (Brown City, MI)    Red
#
#                                                        Product DeliveryDate  \
# InvoiceDate
# 2014-05-12                    Void fill 100 L bag (White) 100L   2014-05-13
# 2014-05-12   Developer joke mug - old C developers never di...   2014-05-13
# 2014-05-12   Developer joke mug - fun was unexpected at thi...   2014-05-13
# 2014-05-12                        USB missile launcher (Green)   2014-05-13
# 2014-05-12          Express post box 5kg (White) 350x280x130mm   2014-05-13
# 2014-05-12              Ride on toy sedan car (Red) 1/12 scale   2014-05-13
#
#                SalesPerson Package  Quantity  Unit Price   Sales  \
# InvoiceDate
# 2014-05-12       Lily Code    Each      50.0       12.50   625.0
# 2014-05-12       Lily Code    Each       8.0       13.00   104.0
# 2014-05-12       Lily Code    Each       7.0       13.00    91.0
# 2014-05-12       Lily Code    Each       1.0       25.00    25.0
# 2014-05-12   Sophia Hinton    Each     100.0        0.95    95.0
# 2014-05-12   Sophia Hinton    Each       8.0      230.00  1840.0
#
#                  SalesGroup  Sale Key
# InvoiceDate
# 2014-05-12   (600.0, 700.0]     84000
# 2014-05-12   (100.0, 200.0]     84001
# 2014-05-12    (-inf, 100.0]     84002
# 2014-05-12    (-inf, 100.0]     84003
# 2014-05-12    (-inf, 100.0]     84086
# 2014-05-12    (1000.0, inf]     84087

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/offset_frequency.html

# %%
#  Let's select the first 6 months of data
df.first(pd.offsets.MonthBegin(6)).head()
# Out:
#                Region        Country         State CustomerCategory  \
# InvoiceDate
# 2013-01-01   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-02   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-05   Americas  United States  Pennsylvania     Novelty Shop
#
#                                     Customer Color  \
# InvoiceDate
# 2013-01-01      Wingtip Toys (Rose Tree, PA)  Blue
# 2013-01-02      Wingtip Toys (Rose Tree, PA)   Red
# 2013-01-04                           Unknown   NaN
# 2013-01-04                           Unknown   NaN
# 2013-01-05   Wingtip Toys (Sarversville, PA)  Blue
#
#                                                        Product DeliveryDate  \
# InvoiceDate
# 2013-01-01                  Superhero action jacket (Blue) 3XL   2013-01-02
# 2013-01-02   RC vintage American toy coupe with remote cont...   2013-01-03
# 2013-01-04                    Medium sized bubblewrap roll 20m   2013-01-05
# 2013-01-04                      USB food flash drive - hot dog   2013-01-05
# 2013-01-05                  Superhero action jacket (Blue) 3XL   2013-01-06
#
#                 SalesPerson Package  Quantity  Unit Price   Sales  \
# InvoiceDate
# 2013-01-01   Kayla Woodcock    Each       2.0        34.0    68.0
# 2013-01-02   Kayla Woodcock    Each       6.0        30.0   180.0
# 2013-01-04        Taj Shand    Each      80.0        20.0  1600.0
# 2013-01-04        Taj Shand    Each       2.0        32.0    64.0
# 2013-01-05        Amy Trefl    Each       4.0        34.0   136.0
#
#                  SalesGroup  Sale Key
# InvoiceDate
# 2013-01-01    (-inf, 100.0]        35
# 2013-01-02   (100.0, 200.0]       119
# 2013-01-04    (1000.0, inf]       584
# 2013-01-04    (-inf, 100.0]       585
# 2013-01-05   (100.0, 200.0]       674

# %%
df.first(pd.offsets.MonthEnd(6)).head()
# Out:
#                Region        Country         State CustomerCategory  \
# InvoiceDate
# 2013-01-01   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-02   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-05   Americas  United States  Pennsylvania     Novelty Shop
#
#                                     Customer Color  \
# InvoiceDate
# 2013-01-01      Wingtip Toys (Rose Tree, PA)  Blue
# 2013-01-02      Wingtip Toys (Rose Tree, PA)   Red
# 2013-01-04                           Unknown   NaN
# 2013-01-04                           Unknown   NaN
# 2013-01-05   Wingtip Toys (Sarversville, PA)  Blue
#
#                                                        Product DeliveryDate  \
# InvoiceDate
# 2013-01-01                  Superhero action jacket (Blue) 3XL   2013-01-02
# 2013-01-02   RC vintage American toy coupe with remote cont...   2013-01-03
# 2013-01-04                    Medium sized bubblewrap roll 20m   2013-01-05
# 2013-01-04                      USB food flash drive - hot dog   2013-01-05
# 2013-01-05                  Superhero action jacket (Blue) 3XL   2013-01-06
#
#                 SalesPerson Package  Quantity  Unit Price   Sales  \
# InvoiceDate
# 2013-01-01   Kayla Woodcock    Each       2.0        34.0    68.0
# 2013-01-02   Kayla Woodcock    Each       6.0        30.0   180.0
# 2013-01-04        Taj Shand    Each      80.0        20.0  1600.0
# 2013-01-04        Taj Shand    Each       2.0        32.0    64.0
# 2013-01-05        Amy Trefl    Each       4.0        34.0   136.0
#
#                  SalesGroup  Sale Key
# InvoiceDate
# 2013-01-01    (-inf, 100.0]        35
# 2013-01-02   (100.0, 200.0]       119
# 2013-01-04    (1000.0, inf]       584
# 2013-01-04    (-inf, 100.0]       585
# 2013-01-05   (100.0, 200.0]       674

# %%
'''The search goes from the first element + the offset to the last element.
DateOffsets have a normalize parameter that, when set to True, sets
all the time components to zero. 
Both the MonthBegin and MonthEnd offsets don't add or subtract an exact amount of time
but effectively round up to the next beginning or end of the month regardless of what day it
is.'''
df.first(pd.offsets.MonthBegin(6, normalize=True)).head()
# Out:
#                Region        Country         State CustomerCategory  \
# InvoiceDate
# 2013-01-01   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-02   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-05   Americas  United States  Pennsylvania     Novelty Shop
#
#                                     Customer Color  \
# InvoiceDate
# 2013-01-01      Wingtip Toys (Rose Tree, PA)  Blue
# 2013-01-02      Wingtip Toys (Rose Tree, PA)   Red
# 2013-01-04                           Unknown   NaN
# 2013-01-04                           Unknown   NaN
# 2013-01-05   Wingtip Toys (Sarversville, PA)  Blue
#
#                                                        Product DeliveryDate  \
# InvoiceDate
# 2013-01-01                  Superhero action jacket (Blue) 3XL   2013-01-02
# 2013-01-02   RC vintage American toy coupe with remote cont...   2013-01-03
# 2013-01-04                    Medium sized bubblewrap roll 20m   2013-01-05
# 2013-01-04                      USB food flash drive - hot dog   2013-01-05
# 2013-01-05                  Superhero action jacket (Blue) 3XL   2013-01-06
#
#                 SalesPerson Package  Quantity  Unit Price   Sales  \
# InvoiceDate
# 2013-01-01   Kayla Woodcock    Each       2.0        34.0    68.0
# 2013-01-02   Kayla Woodcock    Each       6.0        30.0   180.0
# 2013-01-04        Taj Shand    Each      80.0        20.0  1600.0
# 2013-01-04        Taj Shand    Each       2.0        32.0    64.0
# 2013-01-05        Amy Trefl    Each       4.0        34.0   136.0
#
#                  SalesGroup  Sale Key
# InvoiceDate
# 2013-01-01    (-inf, 100.0]        35
# 2013-01-02   (100.0, 200.0]       119
# 2013-01-04    (1000.0, inf]       584
# 2013-01-04    (-inf, 100.0]       585
# 2013-01-05   (100.0, 200.0]       674

# %%
df.loc[:'2016-06'].head()
# Out:
#                Region        Country         State CustomerCategory  \
# InvoiceDate
# 2013-01-01   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-02   Americas  United States  Pennsylvania     Novelty Shop
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-04   Americas  United States      Michigan              NaN
# 2013-01-05   Americas  United States  Pennsylvania     Novelty Shop
#
#                                     Customer Color  \
# InvoiceDate
# 2013-01-01      Wingtip Toys (Rose Tree, PA)  Blue
# 2013-01-02      Wingtip Toys (Rose Tree, PA)   Red
# 2013-01-04                           Unknown   NaN
# 2013-01-04                           Unknown   NaN
# 2013-01-05   Wingtip Toys (Sarversville, PA)  Blue
#
#                                                        Product DeliveryDate  \
# InvoiceDate
# 2013-01-01                  Superhero action jacket (Blue) 3XL   2013-01-02
# 2013-01-02   RC vintage American toy coupe with remote cont...   2013-01-03
# 2013-01-04                    Medium sized bubblewrap roll 20m   2013-01-05
# 2013-01-04                      USB food flash drive - hot dog   2013-01-05
# 2013-01-05                  Superhero action jacket (Blue) 3XL   2013-01-06
#
#                 SalesPerson Package  Quantity  Unit Price   Sales  \
# InvoiceDate
# 2013-01-01   Kayla Woodcock    Each       2.0        34.0    68.0
# 2013-01-02   Kayla Woodcock    Each       6.0        30.0   180.0
# 2013-01-04        Taj Shand    Each      80.0        20.0  1600.0
# 2013-01-04        Taj Shand    Each       2.0        32.0    64.0
# 2013-01-05        Amy Trefl    Each       4.0        34.0   136.0
#
#                  SalesGroup  Sale Key
# InvoiceDate
# 2013-01-01    (-inf, 100.0]        35
# 2013-01-02   (100.0, 200.0]       119
# 2013-01-04    (1000.0, inf]       584
# 2013-01-04    (-inf, 100.0]       585
# 2013-01-05   (100.0, 200.0]       674

# %% [markdown]
# # Counting the number of weekly insert stuff here

# %%
df.resample('W')
# Out:
# DatetimeIndexResampler [freq=<Week: weekday=6>, axis=0, closed=right, label=right, convention=start, base=0]

# %%
weekly_df = df.resample('W').sum()
weekly_df.drop(['Sale Key'], axis=1, inplace=True)

# %%
weekly_df.head()
# Out:
#              Quantity  Unit Price     Sales
# InvoiceDate
# 2013-01-06       94.0      150.00   2048.00
# 2013-01-13      363.0      778.89  17681.25
# 2013-01-20      902.0     2108.24  24711.40
# 2013-01-27      312.0      564.00   9346.00
# 2013-02-03     1872.0     3018.76  40860.10

# %%
weekly_df_gby = df.groupby(pd.Grouper(freq='W')) \
.mean()
weekly_df_gby.drop(['Sale Key'], axis=1, inplace=True)
weekly_df_gby.head()
# Out:
#               Quantity  Unit Price        Sales
# InvoiceDate
# 2013-01-06   18.800000   30.000000   409.600000
# 2013-01-13   25.928571   55.635000  1262.946429
# 2013-01-20   60.133333  140.549333  1647.426667
# 2013-01-27   26.000000   47.000000   778.833333
# 2013-02-03   56.727273   91.477576  1238.184848

# %%
'''It is possible to use resample even when the index does not contain a Timestamp. You can
use the on parameter to select the column with Timestamps that will be used to form groups: '''
weekly_df2 = df.resample('W', on='DeliveryDate').size()
weekly_df2.equals(weekly_df)
# Out:
# False

# %%
# Does it make sense? No! Is it working? Yes!
weekly_df['Unit Price'].plot(figsize=(16, 4),color=['red'], title='Unit Price and Quantity')
weekly_df['Quantity'].plot(figsize=(16, 4),color=['blue'])
plt.show()

# %%
quarterly_df_gby = df.groupby(pd.Grouper(freq='Q')) \
.mean()
quarterly_df_gby.drop(['Sale Key'], axis=1, inplace=True)
quarterly_df_gby.head()
# Out:
#               Quantity  Unit Price       Sales
# InvoiceDate
# 2013-03-31   41.203540   59.533850  868.228097
# 2013-06-30   38.174419   42.570116  783.789729
# 2013-09-30   39.828947   62.834342  887.629386
# 2013-12-31   37.570175   40.930789  685.421272
# 2014-03-31   42.557940   53.333734  878.094850

# %%
quarterly_df_gby['Unit Price'].plot(figsize=(16, 4),color=['red'], title='Unit Price and Quantity')
quarterly_df_gby['Quantity'].plot(figsize=(16, 4),color=['blue'])
plt.show()

# %%
wd_counts=df['DeliveryDate'].dt.weekday_name \
.value_counts()
wd_counts.head()
# Out:
# Tuesday      407
# Thursday     380
# Wednesday    357
# Friday       356
# Saturday     330
# Name: DeliveryDate, dtype: int64

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday',
'Friday', 'Saturday', 'Sunday']
title = 'Number of sales per Weekday'
wd_counts.reindex(days).plot(kind='barh', title=title)
plt.show()

# %%
sns.heatmap(quarterly_df_gby[['Sales']], cmap='Greys')
plt.show()

# %% [markdown]
# # Visualization

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1999 entries, 2013-01-01 to 2016-05-31
# Data columns (total 15 columns):
# Region              1999 non-null category
# Country             1999 non-null category
# State               1999 non-null category
# CustomerCategory    1163 non-null category
# Customer            1999 non-null object
# Color               1196 non-null category
# Product             1999 non-null object
# DeliveryDate        1996 non-null datetime64[ns]
# SalesPerson         1999 non-null object
# Package             1999 non-null category
# Quantity            1999 non-null float64
# Unit Price          1999 non-null float64
# Sales               1999 non-null float64
# SalesGroup          1999 non-null category
# Sale Key            1999 non-null int64
# dtypes: category(7), datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 195.3+ KB

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
fig.set_facecolor('.9')
ax.set_facecolor('.7')
spines = ax.spines
spine_left = spines['left']
spine_left.set_position(('outward', -100))
spine_left.set_linewidth(5)
spine_bottom = spines['bottom']
spine_bottom.set_visible(False)

# %%
ax.xaxis.grid(True, which='major', linewidth=2,
color='black', linestyle='--')
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis Berci', family='Verdana',fontsize=15)
ax.set_title('Title placeholder', dict(fontsize=20, family='Verdana'))
ax.set_ylabel('Y Axis Balázs', family='Calibri', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
fig

# %%
df[['State','Sales']].plot()
plt.show()

# %%
sns.boxplot(x='State', y='Sales', data=df[['State','Sales']], 
hue='State', palette='Greys')
ax.figure.set_size_inches(14,4)
plt.show()

# %% [markdown]
# # We will study the topic of time series and visualizations in separate notebooks.
